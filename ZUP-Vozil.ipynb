# %%
import numpy as np # Uvozimo knjižnico numpy
from tkinter import * # Tkinter je knjižnica znotraj Pythona
# * pomeni da uvozimo celo knjižnico
from tkinter import ttk # Za kombinirana polja
from tkinter import messagebox # Za sporočila
from idlelib.tooltip import Hovertip # Za razlago oken parametrov
root = Tk() # Definiramo Tk je modul znotraj tkintera. Ustvarimo okno
# Definiramo naslov programa
root.title('Programsko orodje za preverjanje zavornega učinka priklopnih vozil') 
root.geometry('1300x700+0+0') # Definiramo kako veliko okno želimo
root.iconbitmap('Priklopnik.ico') # Definiramo ikono v programu

'''Okvirji'''
CelotenOkvir = Frame(root, borderwidth=10)
CelotenOkvir.pack(fill=BOTH, expand=1) 

LeviOkvir = Frame(CelotenOkvir)
LeviOkvir.pack(side=LEFT, fill=BOTH, expand=1)

DesniOkvir = Frame(CelotenOkvir, relief=RIDGE, borderwidth=4)
DesniOkvir.pack(side=RIGHT, fill=BOTH, expand=1)


f0 = Frame(LeviOkvir, width=600, height=120, borderwidth=5)
f0.pack(side=TOP, fill=BOTH)

f1 = Frame(LeviOkvir, relief=RIDGE, borderwidth=4)
f1.pack(fill=BOTH, expand=1)

f2 = Frame(DesniOkvir, borderwidth=5)
f2.pack(fill=BOTH, expand=1)



''' Okno za izpis rezultatov '''
Izpis_Scroll = Scrollbar(f2)
Izpis_Scroll.pack(side=RIGHT, fill=Y)

Izpis = Text(f2, font=('Times new roman', 11), yscrollcommand=Izpis_Scroll.set)
Izpis.pack(fill=BOTH, expand=1)
Izpis_Scroll.configure(command=Izpis.yview)



'''Podatki za vrsto preračuna'''
# Vrsta priklopnika za preračun
priklopnik = ['Izberi vrsto priklopnika','Priklopnik s centralno osjo']

# Število osi
os = ['Izberi število osi','Ena os','Dve osi','Tri osi']

# Vrsta zavor
zavore = ['Izberi tip zavor','Pnevmatske zavore','Hidravlične zavore']

# Hitrosti
hitrost = ['Izberi hitrost','25','40','50','60','80']

# Minimalni zavorni učinek po predpisih
Predpisi_z = ['35', '50']





'''Funckije'''
#Vhodni parmetri
L = StringVar()
h = StringVar()
p = StringVar()
p_max = StringVar()
pI = StringVar()
pII = StringVar()
d = StringVar()
z_min = StringVar()
μ = StringVar()
R = StringVar()
BF1 = StringVar()
BF2 = StringVar()
BF3 = StringVar()
G1 = StringVar()
G2 = StringVar()
G3 = StringVar()
Rp1 = StringVar()
Rp2 = StringVar()
Rp3 = StringVar()
Rb1 = StringVar()
Rb2 = StringVar()
Rb3 = StringVar()
Rr1 = StringVar()
Rr2 = StringVar()
Rr3 = StringVar()
Ro1 = StringVar()
Ro2 = StringVar()
Ro3 = StringVar()
n1 = StringVar()
n2 = StringVar()
n3 = StringVar()
M1_max = StringVar()
M2_max = StringVar()
M3_max = StringVar()

#Izračunani parametri
txt_M1_z = StringVar()
txt_M2_z = StringVar()
txt_M3_z = StringVar()
txt_M_cel = StringVar()
txt_zav_uc = StringVar()
txt_F_pr = StringVar()
txt_F_vo = StringVar()
txt_N1 = StringVar()
txt_N2 = StringVar()
txt_N3 = StringVar()
txt_z_N1 = StringVar()
txt_z_N2 = StringVar()
txt_z_N3 = StringVar()
txt_M1_mog = StringVar()
txt_M2_mog = StringVar()
txt_M3_mog = StringVar()
txt_μ = StringVar()
txt_M1_max = StringVar()
txt_M2_max = StringVar()
txt_M3_max = StringVar()




def Enacbe():
    '''Funkcija sprejme nize parametrov, ki jih vnesemo
    v program, jih pretvori v decimalno število in
    na koncu izpiše rezultate izračunanih parametrov v nizih.'''
    #Parametri potrebni za izračun
    g = 9.81 # [m/s^2]
         
    if dropdown1.get() == priklopnik[0] or dropdown2.get() == os[0] or dropdown3.get() == zavore[0]:
        messagebox.showerror(title='Opozorilo', 
                            message='Izberite vsa kombinirana polja!')

    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[1] and dropdown3.get() == zavore[1]: 
        if dropdown4.get() == hitrost[0]:
            messagebox.showerror(title='Opozorilo', message='Izberite hitrost!')
        elif ( p.get() == '' or pI.get() == '' or pII.get() == '' or BF1.get() == '' or Rr1.get() == '' or 
              n1.get() == '' or R.get() == '' or G1.get() == '' or Rp1.get() == '' or h.get() == '' or L.get() == '' or 
              p_max.get() == '' or μ.get() == '' or z_min.get() == '' or M1_max.get() == '' ):
            messagebox.showerror(title='Opozorilo', message='Izpolnite vsa polja vhodnih parametrov!')
        else:
            if ( (p.get()).find(',') or (pI.get()).find(',') or (pII.get()).find(',') or (BF1.get()).find(',') or 
                (Rr1.get()).find(',') or (n1.get()).find(',') or (R.get()).find(',') or (G1.get()).find(',') or 
                (Rp1.get()).find(',') or (h.get()).find(',') or (L.get()).find(',') or (p_max.get()).find(',') or 
                (μ.get()).find(',') or (M1_max.get()).find(',') ):
                f_p = float((p.get()).replace(',','.'))
                f_pI = float((pI.get()).replace(',','.'))
                f_pII = float((pII.get()).replace(',','.'))
                f_BF1 = float((BF1.get()).replace(',','.'))
                f_Rr1 = float((Rr1.get()).replace(',','.'))
                f_n1 = float((n1.get()).replace(',','.'))
                f_R = float((R.get()).replace(',','.'))
                f_G1 = float((G1.get()).replace(',','.'))
                f_Rp1 = float((Rp1.get()).replace(',','.'))
                f_h = float((h.get()).replace(',','.'))
                f_L = float((L.get()).replace(',','.'))
                f_p_max = float((p_max.get()).replace(',','.'))
                f_μ = float((μ.get()).replace(',','.'))
                f_M1_max = float((M1_max.get()).replace(',','.'))
            else:    
                f_p = float(p.get()) 
                f_pI = float(pI.get())
                f_pII = float(pII.get())
                f_BF1 = float(BF1.get())
                f_Rr1 = float(Rr1.get())
                f_n1 = float(n1.get())
                f_R = float(R.get())
                f_G1 = float(G1.get())
                f_Rp1 = float(Rp1.get())
                f_h = float(h.get())
                f_L = float(L.get())
                f_p_max = float(p_max.get())
                f_μ = float(μ.get())
                f_M1_max = float(M1_max.get())

        txt_M1_max.set(f_M1_max)
       
        M1_z = (f_pI*f_p-f_pII) * f_Rr1* f_BF1 * f_n1
        flo_M1_z = ('%.2f' % ((M1_z)))
        txt_M1_z.set(flo_M1_z)
        
        zav_uc = (M1_z * (100-f_R)/(f_G1 * g * f_Rp1))
        flo_zav_uc = ('%.2f' % ((zav_uc)))
        txt_zav_uc.set(flo_zav_uc)
        
        F_pr = (f_G1 * g * 13.5 * f_h / (100 * f_L))
        flo_F_pr = ('%.2f' % ((F_pr)))
        txt_F_pr.set(flo_F_pr)
        
        F_vo = (F_pr)
        flo_F_vo = ('%.2f' % ((F_vo)))
        txt_F_vo.set(flo_F_vo)
        
        N1 = (f_G1*g - F_pr)
        flo_N1 = ('%.2f' % ((N1)))
        txt_N1.set(flo_N1)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        flo_z_N1 = ('%.2f' % ((z_N1)))
        txt_z_N1.set(flo_z_N1)
        
        M1_mog = (f_pI*f_p_max-f_pII) * f_Rr1* f_BF1 * f_n1
        flo_M1_mog = ('%.2f' % ((M1_mog)))
        txt_M1_mog.set(flo_M1_mog)
        
        μ_ = (f_μ*100)
        flo_μ = ('%.2f' % ((μ_)))
        txt_μ.set(flo_μ)

        Izpis.insert(END, '1 - Zavorni moment \n M1_z = (pI*p-pII) * Rr1 * BF1 * n1  \t\t\t\t\t = \t'+txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Teoretični zavorni učinek \n z = M1_z * (100-R) / (G1 * g * Rp1)  \t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 3 - Dinamična preobremenitev \n F_pr = G1 * g * 13.5 * h / (100 * L)  \t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 4 - Dinamična obremenitev vlečnega ojesa \n N_vo = F_pr  \t\t\t\t\t = \t'
                     +txt_F_vo.get()+' N')
        Izpis.insert(END, '\n\n 5 - Dinamična obremenitev osi \n N1 = G1 * g - F_pr  \t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 6 - Dinamični zavorni izkoristek osi \n z_N1 = M1_z * (100-R) / (N1 * Rp)   \t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 7 - Največji mogoč zavorni moment \n M1_mog = (pI*p_max-pII) * Rr1 * BF1 * n1 \t\t=       \t\t\t\t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+txt_M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 8 - Zdrs osi \n z_N1   ≤   μ * 100     \t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        
        if zav_uc >= float(z_min.get()) and M1_mog <= f_M1_max and z_N1 <= μ_:
            messagebox.showinfo(title='Sporočilo', 
                                message='Vhodni parametri ustrezajo potrebnim pogojem!')
        else:
            messagebox.showerror(title='Opozorilo', 
                                 message='Vhodni parametri ne ustrezajo potrebnim pogojem. Spremenite vhodne parametre!')
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[2] and dropdown3.get() == zavore[1]:
        if dropdown4.get() == hitrost[0]:
            messagebox.showerror(title='Opozorilo', message='Izberite hitrost!')
        elif ( p.get() == '' or pI.get() == '' or pII.get() == '' or BF1.get() == '' or BF2.get() == '' or 
              Rr1.get() == '' or Rr2.get() == '' or n1.get() == '' or n2.get() == '' or R.get() == '' or 
              G1.get() == '' or G2.get() == '' or Rp1.get() == '' or Rp2.get() == '' or h.get() == '' or 
              L.get() == '' or p_max.get() == '' or μ.get() == '' or z_min.get() == '' or M1_max.get() == '' or 
              M2_max.get() == '' ):
            messagebox.showerror(title='Opozorilo', message='Izpolnite vsa polja vhodnih parametrov!')
        else:
            if ( (p.get()).find(',') or (pI.get()).find(',') or (pII.get()).find(',') or (BF1.get()).find(',') or 
                (BF2.get()).find(',') or (Rr1.get()).find(',') or (Rr2.get()).find(',') or (n1.get()).find(',') or 
                (n2.get()).find(',') or (R.get()).find(',') or (G1.get()).find(',') or (G2.get()).find(',') or 
                (Rp1.get()).find(',') or (Rp2.get()).find(',') or (h.get()).find(',') or (L.get()).find(',') or 
                (p_max.get()).find(',') or (μ.get()).find(',') or (M1_max.get()).find(',') or (M2_max.get()).find(',') ):
                f_p = float((p.get()).replace(',','.'))
                f_pI = float((pI.get()).replace(',','.'))
                f_pII = float((pII.get()).replace(',','.'))
                f_BF1 = float((BF1.get()).replace(',','.'))
                f_BF2 = float((BF2.get()).replace(',','.'))
                f_Rr1 = float((Rr1.get()).replace(',','.'))
                f_Rr2 = float((Rr2.get()).replace(',','.'))
                f_n1 = float((n1.get()).replace(',','.'))
                f_n2 = float((n2.get()).replace(',','.'))
                f_R = float((R.get()).replace(',','.'))
                f_G1 = float((G1.get()).replace(',','.'))
                f_G2 = float((G2.get()).replace(',','.'))
                f_Rp1 = float((Rp1.get()).replace(',','.'))
                f_Rp2 = float((Rp2.get()).replace(',','.'))
                f_h = float((h.get()).replace(',','.'))
                f_L = float((L.get()).replace(',','.'))
                f_p_max = float((p_max.get()).replace(',','.'))
                f_μ = float((μ.get()).replace(',','.'))
                f_M1_max = float((M1_max.get()).replace(',','.'))
                f_M2_max = float((M2_max.get()).replace(',','.'))
            else:
                f_L = float(L.get())
                f_p = float(p.get()) 
                f_pI = float(pI.get())
                f_pII = float(pII.get())
                f_BF1 = float(BF1.get())
                f_BF2 = float(BF2.get())
                f_Rr1 = float(Rr1.get())
                f_Rr2 = float(Rr2.get())
                f_n1 = float(n1.get())
                f_n2 = float(n2.get())
                f_R = float(R.get())
                f_G1 = float(G1.get())
                f_G2 = float(G2.get())
                f_Rp1 = float(Rp1.get())
                f_Rp2 = float(Rp2.get())
                f_h = float(h.get())
                f_p_max = float(p_max.get())
                f_μ = float(μ.get())
                f_M1_max = float(M1_max.get())
                f_M2_max = float(M2_max.get())

        txt_M1_max.set(f_M1_max)
        txt_M2_max.set(f_M2_max)
        
        M1_z = (f_pI*f_p-f_pII) * f_Rr1 * f_BF1 * f_n1
        flo_M1_z = ('%.2f' % ((M1_z)))
        txt_M1_z.set(flo_M1_z)
        
        M2_z = (f_pI*f_p-f_pII) * f_Rr2* f_BF2 * f_n2
        flo_M2_z = ('%.2f' % ((M2_z)))
        txt_M2_z.set(flo_M2_z)
        
        M_cel = (M1_z + M2_z)
        flo_M_cel = ('%.2f' % ((M_cel)))
        txt_M_cel.set(flo_M_cel)
        
        zav_uc = (M_cel * (100-f_R)/(f_G1 * g * f_Rp1 + f_G2 * g * f_Rp2))
        flo_zav_uc = ('%.2f' % ((zav_uc)))
        txt_zav_uc.set(flo_zav_uc)      
        
        F_pr = ((f_G1+f_G2) * g * 13.5 * f_h / (100 * f_L))
        flo_F_pr = ('%.2f' % ((F_pr)))
        txt_F_pr.set(flo_F_pr)
        
        N1 = (f_G1*g + F_pr)
        flo_N1 = ('%.2f' % ((N1)))
        txt_N1.set(flo_N1)
        
        N2 = (f_G2*g - F_pr)
        flo_N2 = ('%.2f' % ((N2)))
        txt_N2.set(flo_N2)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        flo_z_N1 = ('%.2f' % ((z_N1)))
        txt_z_N1.set(flo_z_N1)
        
        z_N2 = (M2_z * (100-f_R) /(N2 * f_Rp2))
        flo_z_N2 = ('%.2f' % ((z_N2)))
        txt_z_N2.set(flo_z_N2)
        
        M1_mog = (f_pI*f_p_max-f_pII) * f_Rr1* f_BF1 * f_n1
        flo_M1_mog = ('%.2f' % ((M1_mog)))
        txt_M1_mog.set(flo_M1_mog)
        
        M2_mog = (f_pI*f_p_max-f_pII) * f_Rr2* f_BF2 * f_n2
        flo_M2_mog = ('%.2f' % ((M2_mog)))
        txt_M2_mog.set(flo_M2_mog)
        
        μ_ = (f_μ*100)
        flo_μ = ('%.2f' % ((μ_)))
        txt_μ.set(flo_μ)

        Izpis.insert(END, '1 - Zavorni moment prve osi \n M1_z = (pI*p-pII) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t = \t'
                     +txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Zavorni moment druge osi \n M2_z = (pI*p-pII) * Rr2 * BF2 * n2  \t\t\t\t\t\t\t = \t'
                     +txt_M2_z.get()+' Nm')
        Izpis.insert(END, '\n\n 3 - Celoten zavorni moment \n M_cel = M1_z + M2_z     \t\t\t\t\t\t\t = \t'+txt_M_cel.get()+' Nm')      
        Izpis.insert(END, '\n\n 4 - Teoretični zavorni učinek \n z = M_cel * (100-R)/(G1 * g * Rp1 + G2 * g * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 5 - Dinamična preobremenitev \n F_pr = (G1+G2) * g * 13.5 * h / (100 * L)  \t\t\t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 6 - Dinamična obremenitev prve osi \n N1 = G1 * g + F_pr  \t\t\t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 7 - Dinamična obremenitev druge osi \n N2 = G2 * g - F_pr \t\t\t\t\t\t\t = \t'+txt_N2.get()+' N')
        Izpis.insert(END, '\n\n 8 - Dinamični zavorni izkoristek prve osi \n z_N1 = M1_z * (100-R) / (N1 * Rp1)   \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 9 - Dinamični zavorni izkoristek druge osi \n z_N2 = M2_z * (100-R) / (N2 * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' %')        
        Izpis.insert(END, '\n\n 10 - Največji mogoč zavorni moment prve osi \n M1_mog = (pI*p_max-pII) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t=       \t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+txt_M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 11 - Največji mogoč zavorni moment druge osi \n M2_mog = (pI*p_max-pII) * Rr2 * BF2 * n2 \t\t\t\t\t\t\t=       \t'
                     +txt_M2_mog.get()+' Nm \t ≤   '+txt_M2_max.get()+' Nm')
        Izpis.insert(END, '\n\n 12 - Zdrs prve osi \n z_N1   ≤   μ * 100     \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 13 - Zdrs druge osi \n z_N2   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' % \t ≤   '+txt_μ.get()+' %')
        
        if ( zav_uc >= float(z_min.get()) and M1_mog <= f_M1_max and M2_mog <= f_M2_max and 
            z_N1 <= μ_ and z_N2 <= μ_ ):
            messagebox.showinfo(title='Sporočilo', 
                                message='Vhodni parametri ustrezajo potrebnim pogojem!')
        else:
            messagebox.showerror(title='Opozorilo', 
                                 message='Vhodni parametri ne ustrezajo potrebnim pogojem. Spremenite vhodne parametre!')        
    
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[3]  and dropdown3.get() == zavore[1]:     
        if dropdown4.get() == hitrost[0]:
            messagebox.showerror(title='Opozorilo', message='Izberite hitrost!')
        elif ( p.get() == '' or pI.get() == '' or pII.get() == '' or BF1.get() == '' or BF2.get() == '' or 
              BF3.get() == '' or Rr1.get() == '' or Rr2.get() == '' or Rr3.get() == '' or n1.get() == '' or 
              n2.get() == '' or n3.get() == '' or R.get() == '' or G1.get() == '' or G2.get() == '' or 
              G3.get() == '' or Rp1.get() == '' or Rp2.get() == '' or Rp3.get() == '' or h.get() == '' or 
              L.get() == '' or p_max.get() == ''or μ.get() == '' or z_min.get() == '' or M1_max.get() == '' or 
              M2_max.get() == '' or M3_max.get() == '' ): 
            messagebox.showerror(title='Opozorilo', message='Izpolnite vsa polja vhodnih parametrov!')
        else:
            if ( (p.get()).find(',') or (pI.get()).find(',') or (pII.get()).find(',') or (BF1.get()).find(',') or 
                (BF2.get()).find(',') or (BF3.get()).find(',') or (Rr1.get()).find(',') or (Rr2.get()).find(',') or 
                (Rr3.get()).find(',') or (n1.get()).find(',') or (n2.get()).find(',') or (n3.get()).find(',') or 
                (R.get()).find(',') or (G1.get()).find(',') or (G2.get()).find(',') or (G3.get()).find(',') or 
                (Rp1.get()).find(',') or (Rp2.get()).find(',') or (Rp3.get()).find(',') or (h.get()).find(',') or 
                (L.get()).find(',') or (p_max.get()).find(',') or (μ.get()).find(',') or (M1_max.get()).find(',') or
                (M2_max.get()).find(',') or (M3_max.get()).find(',') ):
                f_p = float((p.get()).replace(',','.'))
                f_pI = float((pI.get()).replace(',','.'))
                f_pII = float((pII.get()).replace(',','.'))
                f_BF1 = float((BF1.get()).replace(',','.'))
                f_BF2 = float((BF2.get()).replace(',','.'))
                f_BF3 = float((BF3.get()).replace(',','.'))
                f_Rr1 = float((Rr1.get()).replace(',','.'))
                f_Rr2 = float((Rr2.get()).replace(',','.'))
                f_Rr3 = float((Rr3.get()).replace(',','.'))
                f_n1 = float((n1.get()).replace(',','.'))
                f_n2 = float((n2.get()).replace(',','.'))
                f_n3 = float((n3.get()).replace(',','.')) 
                f_R = float((R.get()).replace(',','.'))
                f_G1 = float((G1.get()).replace(',','.'))
                f_G2 = float((G2.get()).replace(',','.'))
                f_G3 = float((G3.get()).replace(',','.'))
                f_Rp1 = float((Rp1.get()).replace(',','.'))
                f_Rp2 = float((Rp2.get()).replace(',','.'))
                f_Rp3 = float((Rp3.get()).replace(',','.'))
                f_h = float((h.get()).replace(',','.'))
                f_L = float((L.get()).replace(',','.'))
                f_p_max = float((p_max.get()).replace(',','.'))
                f_μ = float((μ.get()).replace(',','.'))
                f_M1_max = float((M1_max.get()).replace(',','.'))
                f_M2_max = float((M2_max.get()).replace(',','.'))
                f_M3_max = float((M3_max.get()).replace(',','.'))
            else:        
                f_p = float(p.get()) 
                f_pI = float(pI.get())
                f_pII = float(pII.get())
                f_BF1 = float(BF1.get())
                f_BF2 = float(BF2.get())
                f_BF3 = float(BF3.get())
                f_Rr1 = float(Rr1.get())
                f_Rr2 = float(Rr2.get())
                f_Rr3 = float(Rr3.get())
                f_n1 = float(n1.get())
                f_n2 = float(n2.get())
                f_n3 = float(n3.get())
                f_R = float(R.get())
                f_G1 = float(G1.get())
                f_G2 = float(G2.get())
                f_G3 = float(G3.get())
                f_Rp1 = float(Rp1.get())
                f_Rp2 = float(Rp2.get())
                f_Rp3 = float(Rp3.get())
                f_h = float(h.get())
                f_L = float(L.get())
                f_p_max = float(p_max.get())
                f_μ = float(μ.get())
                f_M1_max = float(M1_max.get())
                f_M2_max = float(M2_max.get())
                f_M3_max = float(M3_max.get())

        txt_M1_max.set(f_M1_max)
        txt_M2_max.set(f_M2_max)        
        txt_M3_max.set(f_M3_max) 
        
        M1_z = (f_pI*f_p-f_pII) * f_Rr1* f_BF1 * f_n1
        flo_M1_z = ('%.2f' % ((M1_z)))
        txt_M1_z.set(flo_M1_z)
        
        M2_z = (f_pI*f_p-f_pII) * f_Rr2* f_BF2 * f_n2
        flo_M2_z = ('%.2f' % ((M2_z)))
        txt_M2_z.set(flo_M2_z)
        
        M3_z = (f_pI*f_p-f_pII) * f_Rr3* f_BF3 * f_n3
        flo_M3_z = ('%.2f' % ((M3_z)))
        txt_M3_z.set(flo_M3_z)
        
        M_cel = (M1_z + M2_z + M3_z)
        flo_M_cel = ('%.2f' % ((M_cel)))
        txt_M_cel.set(flo_M_cel)
        
        zav_uc = (M_cel * (100-f_R)/(f_G1 * g * f_Rp1 + f_G2 * g * f_Rp2 + f_G3 * g * f_Rp3))
        flo_zav_uc = ('%.2f' % ((zav_uc)))
        txt_zav_uc.set(flo_zav_uc)      
        
        F_pr = ((f_G1+f_G2+f_G3) * g * 13.5 * f_h / (100 * f_L))
        flo_F_pr = ('%.2f' % ((F_pr)))
        txt_F_pr.set(flo_F_pr)
        
        N1 = (f_G1*g + F_pr)
        flo_N1 = ('%.2f' % ((N1)))
        txt_N1.set(flo_N1)
        
        N2 = (f_G2*g)
        flo_N2 = ('%.2f' % ((N2)))
        txt_N2.set(flo_N2)
        
        N3 = (f_G3*g - F_pr)
        flo_N3 = ('%.2f' % ((N3)))
        txt_N3.set(flo_N3)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        flo_z_N1 = ('%.2f' % ((z_N1)))
        txt_z_N1.set(flo_z_N1)
        
        z_N2 = (M2_z * (100-f_R) /(N2 * f_Rp2))
        flo_z_N2 = ('%.2f' % ((z_N2)))
        txt_z_N2.set(flo_z_N2)
        
        z_N3 = (M3_z * (100-f_R) /(N3 * f_Rp3))
        flo_z_N3 = ('%.2f' % ((z_N3)))
        txt_z_N3.set(flo_z_N3)
        
        M1_mog = (f_pI*f_p_max-f_pII) * f_Rr1* f_BF1 * f_n1
        flo_M1_mog = ('%.2f' % ((M1_mog)))
        txt_M1_mog.set(flo_M1_mog)
        
        M2_mog = (f_pI*f_p_max-f_pII) * f_Rr2* f_BF2 * f_n2
        flo_M2_mog = ('%.2f' % ((M2_mog)))
        txt_M2_mog.set(flo_M2_mog)
        
        M3_mog = (f_pI*f_p_max-f_pII) * f_Rr3* f_BF3 * f_n3
        flo_M3_mog = ('%.2f' % ((M3_mog)))
        txt_M3_mog.set(flo_M3_mog)
        
        μ_ = (f_μ*100)
        flo_μ = ('%.2f' % ((μ_)))
        txt_μ.set(flo_μ)

        Izpis.insert(END, '1 - Zavorni moment prve osi \n M1_z = (pI*p-pII) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t = \t'
                     +txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Zavorni moment druge osi \n M2_z = (pI*p-pII) * Rr2 * BF2 * n2  \t\t\t\t\t\t\t = \t'
                     +txt_M2_z.get()+' Nm')
        Izpis.insert(END, '\n\n 3 - Zavorni moment tretje osi \n M3_z = (pI*p-pII) * Rr3 * BF3 * n3  \t\t\t\t\t\t\t = \t'
                     +txt_M3_z.get()+' Nm')
        Izpis.insert(END, '\n\n 4 - Celoten zavorni moment \n M_cel = M1_z + M2_z + M3_z    \t\t\t\t\t\t\t = \t'+txt_M_cel.get()+' Nm')      
        Izpis.insert(END, '\n\n 5 - Teoretični zavorni učinek \n z = M_cel * (100-R)/(G1 * g * Rp1 + G2 * g * Rp2 + G3 * g * Rp3)  \t\t\t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 6 - Dinamična preobremenitev \n F_pr = (G1+G2+G3) * g * 13.5 * h / (100 * L)  \t\t\t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 7 - Dinamična obremenitev prve osi \n N1 = G1 * g + F_pr  \t\t\t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 8 - Dinamična obremenitev druge osi \n N2 = G2 * g \t\t\t\t\t\t\t = \t'+txt_N2.get()+' N')
        Izpis.insert(END, '\n\n 9 - Dinamična obremenitev tretje osi \n N3 = G3 * g - F_pr \t\t\t\t\t\t\t = \t'+txt_N3.get()+' N')
        Izpis.insert(END, '\n\n 10 - Dinamični zavorni izkoristek prve osi \n z_N1 = M1_z * (100-R) / (N1 * Rp1)   \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 11 - Dinamični zavorni izkoristek druge osi \n z_N2 = M2_z * (100-R) / (N2 * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' %')        
        Izpis.insert(END, '\n\n 12 - Dinamični zavorni izkoristek tretje osi \n z_N3 = M3_z * (100-R) / (N3 * Rp3)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N3.get()+' %')
        Izpis.insert(END, '\n\n 13 - Največji mogoč zavorni moment prve osi \n M1_mog = (pI*p_max-pII) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t=       \t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+txt_M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 14 - Največji mogoč zavorni moment druge osi \n M2_mog = (pI*p_max-pII) * Rr2 * BF2 * n2 \t\t\t\t\t\t\t=       \t'
                     +txt_M2_mog.get()+' Nm \t ≤   '+txt_M2_max.get()+' Nm')
        Izpis.insert(END, '\n\n 15 - Največji mogoč zavorni moment tretje osi \n M3_mog = (pI*p_max-pII) * Rr3 * BF3 * n3 \t\t\t\t\t\t\t=       \t'
                     +txt_M3_mog.get()+' Nm \t ≤   '+txt_M3_max.get()+' Nm')
        Izpis.insert(END, '\n\n 16 - Zdrs prve osi \n z_N1   ≤   μ * 100     \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 17 - Zdrs druge osi \n z_N2   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 18 - Zdrs tretje osi \n z_N3   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N3.get()+' % \t ≤   '+txt_μ.get()+' %')
        
        if ( zav_uc >= float(z_min.get()) and M1_mog <= f_M1_max and M2_mog <= f_M2_max and 
            M3_mog <= f_M3_max and z_N1 <= μ_ and z_N2 <= μ_ and z_N3 <= μ_ ):
            messagebox.showinfo(title='Sporočilo', 
                                message='Vhodni parametri ustrezajo potrebnim pogojem!')
        else:
            messagebox.showerror(title='Opozorilo', 
                                 message='Vhodni parametri ne ustrezajo potrebnim pogojem. Spremenite vhodne parametre!')        
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[1] and dropdown3.get() == zavore[2]:
        if dropdown4.get() == hitrost[0]:
            messagebox.showerror(title='Opozorilo', message='Izberite hitrost!')
        elif ( p.get() == '' or d.get() == '' or BF1.get() == '' or Rr1.get() == '' or n1.get() == '' or 
              R.get() == '' or G1.get() == '' or Rp1.get() == '' or h.get() == '' or L.get() == '' or 
              p_max.get() == ''or μ.get() == '' or z_min.get() == '' or M1_max.get() == '' ):
            messagebox.showerror(title='Opozorilo', message='Izpolnite vsa polja vhodnih parametrov!')
        else:
            if ( (p.get()).find(',') or (d.get()).find(',') or (BF1.get()).find(',') or (Rr1.get()).find(',') or
                (n1.get()).find(',') or (R.get()).find(',') or (G1.get()).find(',') or (Rp1.get()).find(',') or 
                (h.get()).find(',') or (L.get()).find(',') or (p_max.get()).find(',') or (μ.get()).find(',') or 
                (M1_max.get()).find(',') ):
                f_p = float((p.get()).replace(',','.'))
                f_d = float((d.get()).replace(',','.'))
                f_BF1 = float((BF1.get()).replace(',','.'))
                f_Rr1 = float((Rr1.get()).replace(',','.'))
                f_n1 = float((n1.get()).replace(',','.'))
                f_R = float((R.get()).replace(',','.'))
                f_G1 = float((G1.get()).replace(',','.'))
                f_Rp1 = float((Rp1.get()).replace(',','.'))
                f_h = float((h.get()).replace(',','.'))
                f_L = float((L.get()).replace(',','.'))
                f_p_max = float((p_max.get()).replace(',','.'))
                f_μ = float((μ.get()).replace(',','.'))
                f_M1_max = float((M1_max.get()).replace(',','.'))    
            else:        
                f_p = float(p.get()) 
                f_d = float(d.get())
                f_BF1 = float(BF1.get())
                f_Rr1 = float(Rr1.get())
                f_n1 = float(n1.get())
                f_R = float(R.get())
                f_G1 = float(G1.get())
                f_Rp1 = float(Rp1.get())
                f_h = float(h.get())
                f_L = float(L.get())
                f_p_max = float(p_max.get())
                f_μ = float(μ.get())
                f_M1_max = float(M1_max.get())
                
        txt_M1_max.set(f_M1_max)        

        M1_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        flo_M1_z = ('%.2f' % ((M1_z)))
        txt_M1_z.set(flo_M1_z)
        
        zav_uc = (M1_z * (100-f_R)/(f_G1 * g * f_Rp1))
        flo_zav_uc = ('%.2f' % ((zav_uc)))
        txt_zav_uc.set(flo_zav_uc)
        
        F_pr = (f_G1 * g * 13.5 * f_h / (100 * f_L))
        flo_F_pr = ('%.2f' % ((F_pr)))
        txt_F_pr.set(flo_F_pr)
        
        F_vo = (F_pr)
        flo_F_vo = ('%.2f' % ((F_vo)))
        txt_F_vo.set(flo_F_vo)
        
        N1 = (f_G1*g - F_pr)
        flo_N1 = ('%.2f' % ((N1)))
        txt_N1.set(flo_N1)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        flo_z_N1 = ('%.2f' % ((z_N1)))
        txt_z_N1.set(flo_z_N1)
        
        M1_mog = ((f_p_max*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        flo_M1_mog = ('%.2f' % ((M1_mog)))
        txt_M1_mog.set(flo_M1_mog)
        
        μ_ = (f_μ*100)
        flo_μ = ('%.2f' % ((μ_)))
        txt_μ.set(flo_μ)

        Izpis.insert(END, '1 - Zavorni moment \n M1_z = (p * (π*d^2/4)) * Rr1 * BF1 * n1  \t\t\t\t\t = \t'+txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Teoretični zavorni učinek \n z = M1_z * (100-R) / (G1 * g * Rp1)  \t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 3 - Dinamična preobremenitev \n F_pr = G1 * g * 13.5 * h / (100 * L)  \t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 4 - Dinamična obremenitev vlečnega ojesa \n N_vo = F_pr  \t\t\t\t\t = \t'
                     +txt_F_vo.get()+' N')
        Izpis.insert(END, '\n\n 5 - Dinamična obremenitev osi \n N1 = G1 * g - F_pr  \t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 6 - Dinamični zavorni izkoristek osi \n z_N1 = M1_z * (100-R) / (N1 * Rp)   \t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 7 - Največji mogoč zavorni moment \n M1_mog = (p_max * (π*d^2/4)) * Rr1 * BF1 * n1 \t\t=       \t\t\t\t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+txt_M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 8 - Zdrs osi \n z_N1   ≤   μ * 100     \t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        
        if zav_uc >= float(z_min.get()) and M1_mog <= f_M1_max and z_N1 <= μ_:
            messagebox.showinfo(title='Sporočilo', 
                                message='Vhodni parametri ustrezajo potrebnim pogojem!')
        else:
            messagebox.showerror(title='Opozorilo', 
                                 message='Vhodni parametri ne ustrezajo potrebnim pogojem. Spremenite vhodne parametre!')        
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[2] and dropdown3.get() == zavore[2]:
        if dropdown4.get() == hitrost[0]:
            messagebox.showerror(title='Opozorilo', message='Izberite hitrost!')
        elif ( p.get() == '' or d.get() == '' or BF1.get() == '' or BF2.get() == '' or Rr1.get() == '' or 
              Rr2.get() == '' or n1.get() == '' or n2.get() == '' or R.get() == '' or G1.get() == '' or 
              G2.get() == '' or Rp1.get() == '' or Rp2.get() == '' or h.get() == '' or L.get() == '' or 
              p_max.get() == ''or μ.get() == '' or z_min.get() == '' or M1_max.get() == '' or M2_max.get() == '' ):
            messagebox.showerror(title='Opozorilo', message='Izpolnite vsa polja vhodnih parametrov!')
        else:
            if ( (p.get()).find(',') or (d.get()).find(',') or (BF1.get()).find(',') or (BF2.get()).find(',') or
                (Rr1.get()).find(',') or (Rr2.get()).find(',') or (n1.get()).find(',') or (n2.get()).find(',') or
                (R.get()).find(',') or (G1.get()).find(',') or (G2.get()).find(',') or (Rp1.get()).find(',') or 
                (Rp2.get()).find(',') or (h.get()).find(',') or (L.get()).find(',') or (p_max.get()).find(',') or 
                (μ.get()).find(',') or (M1_max.get()).find(',') or (M2_max.get()).find(',') ):
                f_p = float((p.get()).replace(',','.'))
                f_d = float((d.get()).replace(',','.'))
                f_BF1 = float((BF1.get()).replace(',','.'))
                f_BF2 = float((BF2.get()).replace(',','.'))
                f_Rr1 = float((Rr1.get()).replace(',','.'))
                f_Rr2 = float((Rr2.get()).replace(',','.'))
                f_n1 = float((n1.get()).replace(',','.'))
                f_n2 = float((n2.get()).replace(',','.'))
                f_R = float((R.get()).replace(',','.'))
                f_G1 = float((G1.get()).replace(',','.'))
                f_G2 = float((G2.get()).replace(',','.'))
                f_Rp1 = float((Rp1.get()).replace(',','.'))
                f_Rp2 = float((Rp2.get()).replace(',','.'))
                f_h = float((h.get()).replace(',','.'))
                f_L = float((L.get()).replace(',','.'))
                f_p_max = float((p_max.get()).replace(',','.'))
                f_μ = float((μ.get()).replace(',','.'))
                f_M1_max = float((M1_max.get()).replace(',','.'))
                f_M2_max = float((M2_max.get()).replace(',','.'))
            else:        
                f_p = float(p.get()) 
                f_d = float(d.get())
                f_BF1 = float(BF1.get())
                f_BF2 = float(BF2.get())
                f_Rr1 = float(Rr1.get())
                f_Rr2 = float(Rr2.get())
                f_n1 = float(n1.get())
                f_n2 = float(n2.get())
                f_R = float(R.get())
                f_G1 = float(G1.get())
                f_G2 = float(G2.get())
                f_Rp1 = float(Rp1.get())
                f_Rp2 = float(Rp2.get())
                f_h = float(h.get())
                f_L = float(L.get())
                f_p_max = float(p_max.get())
                f_μ = float(μ.get())
                f_M1_max = float(M1_max.get())
                f_M2_max = float(M2_max.get())
                
        txt_M1_max.set(f_M1_max)        
        txt_M2_max.set(f_M2_max)

        M1_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        flo_M1_z = ('%.2f' % ((M1_z)))
        txt_M1_z.set(flo_M1_z)
        
        M2_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr2* f_BF2 * f_n2)
        flo_M2_z = ('%.2f' % ((M2_z)))
        txt_M2_z.set(flo_M2_z)
        
        M_cel = (M1_z + M2_z)
        flo_M_cel = ('%.2f' % ((M_cel)))
        txt_M_cel.set(flo_M_cel)
        
        zav_uc = (M_cel * (100-f_R)/(f_G1 * g * f_Rp1 + f_G2 * g * f_Rp2))
        flo_zav_uc = ('%.2f' % ((zav_uc)))
        txt_zav_uc.set(flo_zav_uc)      
        
        F_pr = ((f_G1+f_G2) * g * 13.5 * f_h / (100 * f_L))
        flo_F_pr = ('%.2f' % ((F_pr)))
        txt_F_pr.set(flo_F_pr)
        
        N1 = (f_G1*g + F_pr)
        flo_N1 = ('%.2f' % ((N1)))
        txt_N1.set(flo_N1)
        
        N2 = (f_G2*g - F_pr)
        flo_N2 = ('%.2f' % ((N2)))
        txt_N2.set(flo_N2)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        flo_z_N1 = ('%.2f' % ((z_N1)))
        txt_z_N1.set(flo_z_N1)
        
        z_N2 = (M2_z * (100-f_R) /(N2 * f_Rp2))
        flo_z_N2 = ('%.2f' % ((z_N2)))
        txt_z_N2.set(flo_z_N2)
        
        M1_mog = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        flo_M1_mog = ('%.2f' % ((M1_mog)))
        txt_M1_mog.set(flo_M1_mog)
        
        M2_mog = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr2* f_BF2 * f_n2)
        flo_M2_mog = ('%.2f' % ((M2_mog)))
        txt_M2_mog.set(flo_M2_mog)
        
        μ_ = (f_μ*100)
        flo_μ = ('%.2f' % ((μ_)))
        txt_μ.set(flo_μ)

        Izpis.insert(END, '1 - Zavorni moment prve osi \n M1_z = (p * (π*d^2/4)) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t = \t'
                     +txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Zavorni moment druge osi \n M2_z = (p * (π*d^2/4)) * Rr2 * BF2 * n2  \t\t\t\t\t\t\t = \t'
                     +txt_M2_z.get()+' Nm')
        Izpis.insert(END, '\n\n 3 - Celoten zavorni moment \n M_cel = M1_z + M2_z     \t\t\t\t\t\t\t = \t'+txt_M_cel.get()+' Nm')      
        Izpis.insert(END, '\n\n 4 - Teoretični zavorni učinek \n z = M_cel * (100-R)/(G1 * g * Rp1 + G2 * g * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 5 - Dinamična preobremenitev \n F_pr = (G1+G2) * g * 13.5 * h / (100 * L)  \t\t\t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 6 - Dinamična obremenitev prve osi \n N1 = G1 * g + F_pr  \t\t\t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 7 - Dinamična obremenitev druge osi \n N2 = G2 * g - F_pr \t\t\t\t\t\t\t = \t'+txt_N2.get()+' N')
        Izpis.insert(END, '\n\n 8 - Dinamični zavorni izkoristek prve osi \n z_N1 = M1_z * (100-R) / (N1 * Rp1)   \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 9 - Dinamični zavorni izkoristek druge osi \n z_N2 = M2_z * (100-R) / (N2 * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' %')        
        Izpis.insert(END, '\n\n 10 - Največji mogoč zavorni moment prve osi \n M1_mog = (p_max * (π*d^2/4)) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t=       \t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+txt_M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 11 - Največji mogoč zavorni moment druge osi \n M2_mog = (p_max * (π*d^2/4)) * Rr2 * BF2 * n2 \t\t\t\t\t\t\t=       \t'
                     +txt_M2_mog.get()+' Nm \t ≤   '+txt_M2_max.get()+' Nm')
        Izpis.insert(END, '\n\n 12 - Zdrs prve osi \n z_N1   ≤   μ * 100     \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 13 - Zdrs druge osi \n z_N2   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' % \t ≤   '+txt_μ.get()+' %')
        
        if zav_uc >= float(z_min.get()) and M1_mog <= f_M1_max and M2_mog <= f_M2_max and z_N1 <= μ_ and z_N2 <= μ_:
            messagebox.showinfo(title='Sporočilo', 
                                message='Vhodni parametri ustrezajo potrebnim pogojem!')
        else:
            messagebox.showerror(title='Opozorilo', 
                                 message='Vhodni parametri ne ustrezajo potrebnim pogojem. Spremenite vhodne parametre!')        
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[3] and dropdown3.get() == zavore[2]:
        if dropdown4.get() == hitrost[0]:
            messagebox.showerror(title='Opozorilo', message='Izberite hitrost!')         
        elif ( p.get() == '' or d.get() == '' or BF1.get() == '' or BF2.get() == '' or BF3.get() == '' or 
              Rr1.get() == '' or Rr2.get() == '' or Rr3.get() == '' or n1.get() == '' or n2.get() == '' or 
              n3.get() == '' or R.get() == '' or G1.get() == '' or G2.get() == '' or G3.get() == '' or 
              Rp1.get() == '' or Rp2.get() == '' or Rp3.get() == '' or h.get() == '' or L.get() == '' or 
              p_max.get() == '' or μ.get() == '' or z_min.get() == '' or M1_max.get() == '' or M2_max.get() == '' or 
              M3_max.get() == '' ):
            messagebox.showerror(title='Opozorilo', message='Izpolnite vsa polja vhodnih parametrov!')
        else:
            if ( (p.get()).find(',') or (d.get()).find(',') or (BF1.get()).find(',') or (BF2.get()).find(',') or 
                (BF3.get()).find(',') or (Rr1.get()).find(',') or (Rr2.get()).find(',') or (Rr3.get()).find(',') or 
                (n1.get()).find(',') or (n2.get()).find(',') or (n3.get()).find(',') or (R.get()).find(',') or 
                (G1.get()).find(',') or (G2.get()).find(',') or (G3.get()).find(',') or (Rp1.get()).find(',') or 
                (Rp2.get()).find(',') or (Rp3.get()).find(',') or (h.get()).find(',') or (L.get()).find(',') or 
                (p_max.get()).find(',') or (μ.get()).find(',') or (M1_max.get()).find(',') or 
                (M2_max.get()).find(',') or (M3_max.get()).find(',') ):
                f_p = float((p.get()).replace(',','.'))
                f_d = float((d.get()).replace(',','.'))
                f_BF1 = float((BF1.get()).replace(',','.'))
                f_BF2 = float((BF2.get()).replace(',','.'))
                f_BF3 = float((BF3.get()).replace(',','.'))
                f_Rr1 = float((Rr1.get()).replace(',','.'))
                f_Rr2 = float((Rr2.get()).replace(',','.'))
                f_Rr3 = float((Rr3.get()).replace(',','.'))
                f_n1 = float((n1.get()).replace(',','.'))
                f_n2 = float((n2.get()).replace(',','.'))
                f_n3 = float((n3.get()).replace(',','.')) 
                f_R = float((R.get()).replace(',','.'))
                f_G1 = float((G1.get()).replace(',','.'))
                f_G2 = float((G2.get()).replace(',','.'))
                f_G3 = float((G3.get()).replace(',','.'))
                f_Rp1 = float((Rp1.get()).replace(',','.'))
                f_Rp2 = float((Rp2.get()).replace(',','.'))
                f_Rp3 = float((Rp3.get()).replace(',','.'))
                f_h = float((h.get()).replace(',','.'))
                f_L = float((L.get()).replace(',','.'))
                f_p_max = float((p_max.get()).replace(',','.'))
                f_μ = float((μ.get()).replace(',','.'))
                f_M1_max = float((M1_max.get()).replace(',','.'))
                f_M2_max = float((M2_max.get()).replace(',','.'))
                f_M3_max = float((M3_max.get()).replace(',','.'))        
            else:        
                f_p = float(p.get()) 
                f_d = float(d.get())
                f_BF1 = float(BF1.get())
                f_BF2 = float(BF2.get())
                f_BF3 = float(BF3.get())
                f_Rr1 = float(Rr1.get())
                f_Rr2 = float(Rr2.get())
                f_Rr3 = float(Rr3.get())
                f_n1 = float(n1.get())
                f_n2 = float(n2.get())
                f_n3 = float(n3.get())
                f_R = float(R.get())
                f_G1 = float(G1.get())
                f_G2 = float(G2.get())
                f_G3 = float(G3.get())
                f_Rp1 = float(Rp1.get())
                f_Rp2 = float(Rp2.get())
                f_Rp3 = float(Rp3.get())
                f_h = float(h.get())
                f_L = float(L.get())
                f_p_max = float(p_max.get())
                f_μ = float(μ.get())
                f_M1_max = float(M1_max.get())
                f_M2_max = float(M2_max.get())
                f_M3_max = float(M3_max.get())

        txt_M1_max.set(f_M1_max)
        txt_M2_max.set(f_M2_max)        
        txt_M3_max.set(f_M3_max) 

        M1_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        flo_M1_z = ('%.2f' % ((M1_z)))
        txt_M1_z.set(flo_M1_z)
        
        M2_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr2* f_BF2 * f_n2)
        flo_M2_z = ('%.2f' % ((M2_z)))
        txt_M2_z.set(flo_M2_z)
        
        M3_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr3* f_BF3 * f_n3)
        flo_M3_z = ('%.2f' % ((M3_z)))
        txt_M3_z.set(flo_M3_z)
        
        M_cel = (M1_z + M2_z + M3_z)
        flo_M_cel = ('%.2f' % ((M_cel)))
        txt_M_cel.set(flo_M_cel)
        
        zav_uc = (M_cel * (100-f_R)/(f_G1 * g * f_Rp1 + f_G2 * g * f_Rp2 + f_G3 * g * f_Rp3))
        flo_zav_uc = ('%.2f' % ((zav_uc)))
        txt_zav_uc.set(flo_zav_uc)      
        
        F_pr = ((f_G1+f_G2+f_G3) * g * 13.5 * f_h / (100 * f_L))
        flo_F_pr = ('%.2f' % ((F_pr)))
        txt_F_pr.set(flo_F_pr)
        
        N1 = (f_G1*g + F_pr)
        flo_N1 = ('%.2f' % ((N1)))
        txt_N1.set(flo_N1)
        
        N2 = (f_G2*g)
        flo_N2 = ('%.2f' % ((N2)))
        txt_N2.set(flo_N2)
        
        N3 = (f_G3*g - F_pr)
        flo_N3 = ('%.2f' % ((N3)))
        txt_N3.set(flo_N3)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        flo_z_N1 = ('%.2f' % ((z_N1)))
        txt_z_N1.set(flo_z_N1)
        
        z_N2 = (M2_z * (100-f_R) /(N2 * f_Rp2))
        flo_z_N2 = ('%.2f' % ((z_N2)))
        txt_z_N2.set(flo_z_N2)
        
        z_N3 = (M3_z * (100-f_R) /(N3 * f_Rp3))
        flo_z_N3 = ('%.2f' % ((z_N3)))
        txt_z_N3.set(flo_z_N3)
        
        M1_mog = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        flo_M1_mog = ('%.2f' % ((M1_mog)))
        txt_M1_mog.set(flo_M1_mog)
        
        M2_mog = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr2* f_BF2 * f_n2)
        flo_M2_mog = ('%.2f' % ((M2_mog)))
        txt_M2_mog.set(flo_M2_mog)
        
        M3_mog = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr3* f_BF3 * f_n3)
        flo_M3_mog = ('%.2f' % ((M3_mog)))
        txt_M3_mog.set(flo_M3_mog)
        
        μ_ = (f_μ*100)
        flo_μ = ('%.2f' % ((μ_)))
        txt_μ.set(flo_μ)

        Izpis.insert(END, '1 - Zavorni moment prve osi \n M1_z = (p * (π*d^2/4)) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t = \t'
                     +txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Zavorni moment druge osi \n M2_z = (p * (π*d^2/4)) * Rr2 * BF2 * n2  \t\t\t\t\t\t\t = \t'
                     +txt_M2_z.get()+' Nm')
        Izpis.insert(END, '\n\n 3 - Zavorni moment tretje osi \n M3_z = (p * (π*d^2/4)) * Rr3 * BF3 * n3  \t\t\t\t\t\t\t = \t'
                     +txt_M3_z.get()+' Nm')
        Izpis.insert(END, '\n\n 4 - Celoten zavorni moment \n M_cel = M1_z + M2_z + M3_z    \t\t\t\t\t\t\t = \t'+txt_M_cel.get()+' Nm')      
        Izpis.insert(END, '\n\n 5 - Teoretični zavorni učinek \n z = M_cel * (100-R)/(G1 * g * Rp1 + G2 * g * Rp2 + G3 * g * Rp3)  \t\t\t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 6 - Dinamična preobremenitev \n F_pr = (G1+G2+G3) * g * 13.5 * h / (100 * L)  \t\t\t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 7 - Dinamična obremenitev prve osi \n N1 = G1 * g + F_pr  \t\t\t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 8 - Dinamična obremenitev druge osi \n N2 = G2 * g \t\t\t\t\t\t\t = \t'+txt_N2.get()+' N')
        Izpis.insert(END, '\n\n 9 - Dinamična obremenitev tretje osi \n N3 = G3 * g - F_pr \t\t\t\t\t\t\t = \t'+txt_N3.get()+' N')
        Izpis.insert(END, '\n\n 10 - Dinamični zavorni izkoristek prve osi \n z_N1 = M1_z * (100-R) / (N1 * Rp1)   \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 11 - Dinamični zavorni izkoristek druge osi \n z_N2 = M2_z * (100-R) / (N2 * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' %')        
        Izpis.insert(END, '\n\n 12 - Dinamični zavorni izkoristek tretje osi \n z_N3 = M3_z * (100-R) / (N3 * Rp3)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N3.get()+' %')
        Izpis.insert(END, '\n\n 13 - Največji mogoč zavorni moment prve osi \n M1_mog = (p_max * (π*d^2/4)) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t=       \t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+txt_M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 14 - Največji mogoč zavorni moment druge osi \n M2_mog = (p_max * (π*d^2/4)) * Rr2 * BF2 * n2 \t\t\t\t\t\t\t=       \t'
                     +txt_M2_mog.get()+' Nm \t ≤   '+txt_M2_max.get()+' Nm')
        Izpis.insert(END, '\n\n 15 - Največji mogoč zavorni moment tretje osi \n M3_mog = (p_max * (π*d^2/4)) * Rr3 * BF3 * n3 \t\t\t\t\t\t\t=       \t'
                     +txt_M3_mog.get()+' Nm \t ≤   '+txt_M3_max.get()+' Nm')
        Izpis.insert(END, '\n\n 16 - Zdrs prve osi \n z_N1   ≤   μ * 100     \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 17 - Zdrs druge osi \n z_N2   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 18 - Zdrs tretje osi \n z_N3   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N3.get()+' % \t ≤   '+txt_μ.get()+' %')
        
        if ( zav_uc >= float(z_min.get()) and M1_mog <= f_M1_max and M2_mog <= f_M2_max and 
            M3_mog <= f_M3_max and z_N1 <= μ_ and z_N2 <= μ_ and z_N3 <= μ_ ):
            messagebox.showinfo(title='Sporočilo', 
                                message='Vhodni parametri ustrezajo potrebnim pogojem!')
        else:
            messagebox.showerror(title='Opozorilo', 
                                 message='Vhodni parametri ne ustrezajo potrebnim pogojem. Spremenite vhodne parametre!')        


        
        

def Izbris_vhodnih_parametrov():
    '''Fukncija izbriše vsak parameter,
    ki je znotraj okvirja f1, ko zamenjamo 
    kombinacijo dropdown menijev'''
    for parametri_vhod in f1.winfo_children():
        parametri_vhod.destroy()



def Vrsta_priklopnika(*args):
    '''Za delovanje funkcija potrebuje *args(nek argumen), ki ga dobi iz 
    menijev, kateri se odprejo (dropdown1,2 in 3). Funkcija glede na izbrane 
    parametre izpiše potreben izračun.'''
    Izbris_vhodnih_parametrov()
    
    if dropdown1.get() == priklopnik[1] and dropdown2.get() == os[1] and dropdown3.get() == zavore[1]:
        for prostor in range(0,20):
            Label(f1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1, text='Razdalja os-vpenjalna naprava', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1, textvariable=L, width=10, font=('Times new roman', 11))
        vnos_L.grid(row=1, column=3, sticky=W)
        tip_L = Hovertip(vnos_L, 'Razdalja med osjo in vpenjalno napravo.')
        enota_L = Label(f1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1, textvariable=p, width=10, font=('Times new roman', 11))
        vnos_p.grid(row=3, column=3, sticky=W)
        tip_p = Hovertip(vnos_p, 'Delovni tlak v sprožilu zavore (ne sme presegati 6,5 bar).')
        enota_p = Label(f1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1, textvariable=p_max, width=10, font=('Times new roman', 11))
        vnos_p_max.grid(row=4, column=3, sticky=W)
        tip_p_max = Hovertip(vnos_p_max, 'Najvišji delovni tlak v sprožilu zavore (ne sme presegati 8 bar).')
        enota_p_max = Label(f1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_pI = Label(f1, text='Prvi parameter zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_pI = Label(f1, text='pI =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_pI = Entry(f1, textvariable=pI, width=10, font=('Times new roman', 11))
        vnos_pI.grid(row=5, column=3, sticky=W)
        tip_pI = Hovertip(vnos_pI, '''Prvi parameter (pI) za izračun sile pnevmatskega zavornega
valja (F), najdemo ga v katalogu proizvajalca zavornih valjev.
Enačba: F = pI · p - pII''')
        enota_pI = Label(f1, text='/', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_pII = Label(f1, text='Drugi parameter zavornega valja', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_pII = Label(f1, text='pII =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        vnos_pII = Entry(f1, textvariable=pII, width=10, font=('Times new roman', 11))
        vnos_pII.grid(row=6, column=3, sticky=W)
        tip_pII = Hovertip(vnos_pII, '''Drugi parameter (pII) za izračun sile pnevmatskega zavornega
valja (F), najdemo ga v katalogu proizvajalca zavornih valjev.
Enačba: F = pI · p - pII''')
        enota_pII = Label(f1, text='/', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        pomen_z_min = Label(f1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_z_min = Label(f1, text='z_min =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        enota_z_min = Label(f1, text='%', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1, textvariable=z_min, width=10, font=('Times new roman', 11))
            vnos_z_min.grid(row=7, column=3, sticky=W)
            tip_z_min = Hovertip(vnos_z_min, '''Velikost zavornega učinka za izbrano hitrost,
po Delegirani uredbi komisile (EU) 2015/68.''')
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_μ = Label(f1, text='μ =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_μ = Entry(f1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_μ = Label(f1, text='/', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        pomen_R = Label(f1, text='Upor ceste', font=('Times new roman', 11)).grid(row=9, column=0, sticky=W)
        oznaka_R = Label(f1, text='R =', font=('Times new roman', 11)).grid(row=9, column=2, sticky=W)
        vnos_R = Entry(f1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=9, column=3, sticky=W)
        enota_R = Label(f1, text='%', font=('Times new roman', 11)).grid(row=9, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1, text='PODATKI OSI', font=('Times new roman', 12, 'bold')).grid(row=11, column=0, sticky=W)
    
        pomen_G1 = Label(f1, text='Masa osi', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_G1 = Label(f1, text='G1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_G1 = Entry(f1, textvariable=G1, width=10, font=('Times new roman', 11))
        vnos_G1.grid(row=12, column=3, sticky=W)
        tip_G1 = Hovertip(vnos_G1, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G1 = Label(f1, text='kg', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_Rp1 = Label(f1, text='Rp1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        vnos_Rp1 = Entry(f1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=13, column=3, sticky=W)
        enota_Rp1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_BF1 = Label(f1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_BF1 = Label(f1, text='BF1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_BF1 = Entry(f1, textvariable=BF1, width=10, font=('Times new roman', 11))
        vnos_BF1.grid(row=14, column=3, sticky=W)
        tip_BF1 = Hovertip(vnos_BF1, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF1 = Label(f1, text='/', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_Rr1 = Label(f1, text='Rr1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_Rr1 = Entry(f1, textvariable=Rr1, width=10, font=('Times new roman', 11))
        vnos_Rr1.grid(row=15, column=3, sticky=W)
        tip_Rr1 = Hovertip(vnos_Rr1, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_n1 = Label(f1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_n1 = Label(f1, text='n1 =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_n1 = Entry(f1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=16, column=3, sticky=W)
        enota_n1 = Label(f1, text='/', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        pomen_M1_max = Label(f1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=17, column=0, sticky=W)
        oznaka_M1_max = Label(f1, text='M1_max =', font=('Times new roman', 11)).grid(row=17, column=2, sticky=W)
        vnos_M1_max = Entry(f1, textvariable=M1_max, width=10, font=('Times new roman', 11))
        vnos_M1_max.grid(row=17, column=3, sticky=W)
        tip_M1_max = Hovertip(vnos_M1_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M1_max = Label(f1, text='Nm', font=('Times new roman', 11)).grid(row=17, column=4, sticky=W)       
   
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[2] and dropdown3.get() == zavore[1]:
    
        f0_1 = Canvas(f1)
        f0_1.pack(side=LEFT, fill=BOTH, expand=1)
        f01_scrollbar = Scrollbar(f1, orient=VERTICAL, command=f0_1.yview)
        f01_scrollbar.pack(side=RIGHT, fill=Y)
        f0_1.configure(yscrollcommand=f01_scrollbar.set)
        f0_1.bind('<Configure>', lambda e: f0_1.configure(scrollregion=f0_1.bbox('all')))
        f1_1 = Frame(f0_1)
        f0_1.create_window((0,0), window=f1_1, anchor='nw')     
        
        for prostor in range(0,27):
            Label(f1_1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1_1, text='PODATKI PRIKLOPNIKA', 
                                    font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1_1, text='Medosna razdalja', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1_1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1_1, textvariable=L, width=10, font=('Times new roman', 11)).grid(row=1, column=3, sticky=W)
        enota_L = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1_1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1_1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1_1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1_1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1_1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1_1, textvariable=p, width=10, font=('Times new roman', 11))
        vnos_p.grid(row=3, column=3, sticky=W)
        tip_p = Hovertip(vnos_p, 'Delovni tlak v sprožilu zavore (ne sme presegati 6,5 bar).')
        enota_p = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1_1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1_1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1_1, textvariable=p_max, width=10, font=('Times new roman', 11))
        vnos_p_max.grid(row=4, column=3, sticky=W)
        tip_p_max = Hovertip(vnos_p_max, 'Najvišji delovni tlak v sprožilu zavore (ne sme presegati 8 bar).')
        enota_p_max = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_pI = Label(f1_1, text='Prvi parameter zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_pI = Label(f1_1, text='pI =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_pI = Entry(f1_1, textvariable=pI, width=10, font=('Times new roman', 11))
        vnos_pI.grid(row=5, column=3, sticky=W)
        tip_pI = Hovertip(vnos_pI, '''Prvi parameter (pI) za izračun sile pnevmatskega zavornega
valja (F), najdemo ga v katalogu proizvajalca zavornih valjev.
Enačba: F = pI · p - pII''')
        enota_pI = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_pII = Label(f1_1, text='Drugi parameter zavornega valja', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_pII = Label(f1_1, text='pII =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        vnos_pII = Entry(f1_1, textvariable=pII, width=10, font=('Times new roman', 11))
        vnos_pII.grid(row=6, column=3, sticky=W)
        tip_pII = Hovertip(vnos_pII, '''Drugi parameter (pII) za izračun sile pnevmatskega zavornega
valja (F), najdemo ga v katalogu proizvajalca zavornih valjev.
Enačba: F = pI · p - pII''')
        enota_pII = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        pomen_z_min = Label(f1_1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_z_min = Label(f1_1, text='z_min =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        enota_z_min = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1_1, textvariable=z_min, width=10, font=('Times new roman', 11))
            vnos_z_min.grid(row=7, column=3, sticky=W)
            tip_z_min = Hovertip(vnos_z_min, '''Velikost zavornega učinka za izbrano hitrost,
po Delegirani uredbi komisile (EU) 2015/68.''')
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1_1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_μ = Label(f1_1, text='μ =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_μ = Entry(f1_1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_μ = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        pomen_R = Label(f1_1, text='Upor ceste', font=('Times new roman', 11)).grid(row=9, column=0, sticky=W)
        oznaka_R = Label(f1_1, text='R =', font=('Times new roman', 11)).grid(row=9, column=2, sticky=W)
        vnos_R = Entry(f1_1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=9, column=3, sticky=W)
        enota_R = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=9, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1_1, text='PODATKI PRVE OSI', font=('Times new roman', 12, 'bold')).grid(row=11, column=0, sticky=W)
    
        pomen_G1 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_G1 = Label(f1_1, text='G1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_G1 = Entry(f1_1, textvariable=G1, width=10, font=('Times new roman', 11))
        vnos_G1.grid(row=12, column=3, sticky=W)
        tip_G1 = Hovertip(vnos_G1, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G1 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_Rp1 = Label(f1_1, text='Rp1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        vnos_Rp1 = Entry(f1_1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=13, column=3, sticky=W)
        enota_Rp1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_BF1 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_BF1 = Label(f1_1, text='BF1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_BF1 = Entry(f1_1, textvariable=BF1, width=10, font=('Times new roman', 11))
        vnos_BF1.grid(row=14, column=3, sticky=W)
        tip_BF1 = Hovertip(vnos_BF1, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_Rr1 = Label(f1_1, text='Rr1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_Rr1 = Entry(f1_1, textvariable=Rr1, width=10, font=('Times new roman', 11))
        vnos_Rr1.grid(row=15, column=3, sticky=W)
        tip_Rr1 = Hovertip(vnos_Rr1, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_n1 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_n1 = Label(f1_1, text='n1 =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_n1 = Entry(f1_1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=16, column=3, sticky=W)
        enota_n1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        pomen_M1_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=17, column=0, sticky=W)
        oznaka_M1_max = Label(f1_1, text='M1_max =', font=('Times new roman', 11)).grid(row=17, column=2, sticky=W)
        vnos_M1_max = Entry(f1_1, textvariable=M1_max, width=10, font=('Times new roman', 11))
        vnos_M1_max.grid(row=17, column=3, sticky=W)
        tip_M1_max = Hovertip(vnos_M1_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M1_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=17, column=4, sticky=W)
        
        Podatki_osi2 = Label(f1_1, text='PODATKI DRUGE OSI', font=('Times new roman', 12, 'bold')).grid(row=19, column=0, sticky=W)
        
        pomen_G2 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=20, column=0, sticky=W)
        oznaka_G2 = Label(f1_1, text='G2 =', font=('Times new roman', 11)).grid(row=20, column=2, sticky=W)
        vnos_G2 = Entry(f1_1, textvariable=G2, width=10, font=('Times new roman', 11))
        vnos_G2.grid(row=20, column=3, sticky=W)
        tip_G2 = Hovertip(vnos_G2, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G2 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=20, column=4, sticky=W)
        
        pomen_Rp2 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=21, column=0, sticky=W)
        oznaka_Rp2 = Label(f1_1, text='Rp2 =', font=('Times new roman', 11)).grid(row=21, column=2, sticky=W)
        vnos_Rp2 = Entry(f1_1, textvariable=Rp2, width=10, font=('Times new roman', 11)).grid(row=21, column=3, sticky=W)
        enota_Rp2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=21, column=4, sticky=W)
        
        pomen_BF2 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=22, column=0, sticky=W)
        oznaka_BF2 = Label(f1_1, text='BF2 =', font=('Times new roman', 11)).grid(row=22, column=2, sticky=W)
        vnos_BF2 = Entry(f1_1, textvariable=BF2, width=10, font=('Times new roman', 11))
        vnos_BF2.grid(row=22, column=3, sticky=W)
        tip_BF2 = Hovertip(vnos_BF2, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=22, column=4, sticky=W)
        
        pomen_Rr2 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=23, column=0, sticky=W)
        oznaka_Rr2 = Label(f1_1, text='Rr2 =', font=('Times new roman', 11)).grid(row=23, column=2, sticky=W)
        vnos_Rr2 = Entry(f1_1, textvariable=Rr2, width=10, font=('Times new roman', 11))
        vnos_Rr2.grid(row=23, column=3, sticky=W)
        tip_Rr2 = Hovertip(vnos_Rr2, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=23, column=4, sticky=W)
        
        pomen_n2 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=24, column=0, sticky=W)
        oznaka_n2 = Label(f1_1, text='n2 =', font=('Times new roman', 11)).grid(row=24, column=2, sticky=W)
        vnos_n2 = Entry(f1_1, textvariable=n2, width=10, font=('Times new roman', 11)).grid(row=24, column=3, sticky=W)
        enota_n2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=24, column=4, sticky=W)
        
        pomen_M2_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=25, column=0, sticky=W)
        oznaka_M2_max = Label(f1_1, text='M2_max =', font=('Times new roman', 11)).grid(row=25, column=2, sticky=W)
        vnos_M2_max = Entry(f1_1, textvariable=M2_max, width=10, font=('Times new roman', 11))
        vnos_M2_max.grid(row=25, column=3, sticky=W)
        tip_M2_max = Hovertip(vnos_M2_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M2_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=25, column=4, sticky=W)

    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[3] and dropdown3.get() == zavore[1]:             
        
        f0_1 = Canvas(f1)
        f0_1.pack(side=LEFT, fill=BOTH, expand=1)
        f01_scrollbar = Scrollbar(f1, orient=VERTICAL, command=f0_1.yview)
        f01_scrollbar.pack(side=RIGHT, fill=Y)
        f0_1.configure(yscrollcommand=f01_scrollbar.set)
        f0_1.bind('<Configure>', lambda e: f0_1.configure(scrollregion=f0_1.bbox('all')))
        f1_1 = Frame(f0_1)
        f0_1.create_window((0,0), window=f1_1, anchor='nw')     

        for prostor in range(0,35):
            Label(f1_1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1_1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1_1, text='Medosna razdalja', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1_1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1_1, textvariable=L, width=10, font=('Times new roman', 11))
        vnos_L.grid(row=1, column=3, sticky=W)
        tip_L = Hovertip(vnos_L, 'Medosna razdalja med prvo in drugo osjo oziroma drugo in tretjo osjo.')
        enota_L = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1_1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1_1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1_1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1_1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1_1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1_1, textvariable=p, width=10, font=('Times new roman', 11))
        vnos_p.grid(row=3, column=3, sticky=W)
        tip_p = Hovertip(vnos_p, 'Delovni tlak v sprožilu zavore (ne sme presegati 6,5 bar).')
        enota_p = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1_1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1_1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1_1, textvariable=p_max, width=10, font=('Times new roman', 11))
        vnos_p_max.grid(row=4, column=3, sticky=W)
        tip_p_max = Hovertip(vnos_p_max, 'Najvišji delovni tlak v sprožilu zavore (ne sme presegati 8 bar).')
        enota_p_max = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_pI = Label(f1_1, text='Prvi parameter zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_pI = Label(f1_1, text='pI =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_pI = Entry(f1_1, textvariable=pI, width=10, font=('Times new roman', 11))
        vnos_pI.grid(row=5, column=3, sticky=W)
        tip_pI = Hovertip(vnos_pI, '''Prvi parameter (pI) za izračun sile pnevmatskega zavornega
valja (F), najdemo ga v katalogu proizvajalca zavornih valjev.
Enačba: F = pI · p - pII''')
        enota_pI = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_pII = Label(f1_1, text='Drugi parameter zavornega valja', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_pII = Label(f1_1, text='pII =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        vnos_pII = Entry(f1_1, textvariable=pII, width=10, font=('Times new roman', 11))
        vnos_pII.grid(row=6, column=3, sticky=W)
        tip_pII = Hovertip(vnos_pII, '''Drugi parameter (pII) za izračun sile pnevmatskega zavornega
valja (F), najdemo ga v katalogu proizvajalca zavornih valjev.
Enačba: F = pI · p - pII''')
        enota_pII = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        pomen_z_min = Label(f1_1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_z_min = Label(f1_1, text='z_min =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        enota_z_min = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1_1, textvariable=z_min, width=10, font=('Times new roman', 11))
            vnos_z_min.grid(row=7, column=3, sticky=W)
            tip_z_min = Hovertip(vnos_z_min, '''Velikost zavornega učinka za izbrano hitrost,
po Delegirani uredbi komisile (EU) 2015/68.''')
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1_1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_μ = Label(f1_1, text='μ =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_μ = Entry(f1_1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_μ = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        pomen_R = Label(f1_1, text='Upor ceste', font=('Times new roman', 11)).grid(row=9, column=0, sticky=W)
        oznaka_R = Label(f1_1, text='R =', font=('Times new roman', 11)).grid(row=9, column=2, sticky=W)
        vnos_R = Entry(f1_1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=9, column=3, sticky=W)
        enota_R = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=9, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1_1, text='PODATKI PRVE OSI', font=('Times new roman', 12, 'bold')).grid(row=11, column=0, sticky=W)
    
        pomen_G1 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_G1 = Label(f1_1, text='G1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_G1 = Entry(f1_1, textvariable=G1, width=10, font=('Times new roman', 11))
        vnos_G1.grid(row=12, column=3, sticky=W)
        tip_G1 = Hovertip(vnos_G1, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G1 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_Rp1 = Label(f1_1, text='Rp1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        vnos_Rp1 = Entry(f1_1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=13, column=3, sticky=W)
        enota_Rp1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_BF1 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_BF1 = Label(f1_1, text='BF1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_BF1 = Entry(f1_1, textvariable=BF1, width=10, font=('Times new roman', 11))
        vnos_BF1.grid(row=14, column=3, sticky=W)
        tip_BF1 = Hovertip(vnos_BF1, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_Rr1 = Label(f1_1, text='Rr1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_Rr1 = Entry(f1_1, textvariable=Rr1, width=10, font=('Times new roman', 11))
        vnos_Rr1.grid(row=15, column=3, sticky=W)
        tip_Rr1 = Hovertip(vnos_Rr1, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_n1 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_n1 = Label(f1_1, text='n1 =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_n1 = Entry(f1_1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=16, column=3, sticky=W)
        enota_n1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        pomen_M1_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=17, column=0, sticky=W)
        oznaka_M1_max = Label(f1_1, text='M1_max =', font=('Times new roman', 11)).grid(row=17, column=2, sticky=W)
        vnos_M1_max = Entry(f1_1, textvariable=M1_max, width=10, font=('Times new roman', 11))
        vnos_M1_max.grid(row=17, column=3, sticky=W)
        tip_M1_max = Hovertip(vnos_M1_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M1_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=17, column=4, sticky=W)
        
        Podatki_osi2 = Label(f1_1, text='PODATKI DRUGE OSI', font=('Times new roman', 12, 'bold')).grid(row=19, column=0, sticky=W)
        
        pomen_G2 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=20, column=0, sticky=W)
        oznaka_G2 = Label(f1_1, text='G2 =', font=('Times new roman', 11)).grid(row=20, column=2, sticky=W)
        vnos_G2 = Entry(f1_1, textvariable=G2, width=10, font=('Times new roman', 11))
        vnos_G2.grid(row=20, column=3, sticky=W)
        tip_G2 = Hovertip(vnos_G2, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G2 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=20, column=4, sticky=W)
        
        pomen_Rp2 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=21, column=0, sticky=W)
        oznaka_Rp2 = Label(f1_1, text='Rp2 =', font=('Times new roman', 11)).grid(row=21, column=2, sticky=W)
        vnos_Rp2 = Entry(f1_1, textvariable=Rp2, width=10, font=('Times new roman', 11)).grid(row=21, column=3, sticky=W)
        enota_Rp2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=21, column=4, sticky=W)
        
        pomen_BF2 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=22, column=0, sticky=W)
        oznaka_BF2 = Label(f1_1, text='BF2 =', font=('Times new roman', 11)).grid(row=22, column=2, sticky=W)
        vnos_BF2 = Entry(f1_1, textvariable=BF2, width=10, font=('Times new roman', 11))
        vnos_BF2.grid(row=22, column=3, sticky=W)
        tip_BF2 = Hovertip(vnos_BF2, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=22, column=4, sticky=W)
        
        pomen_Rr2 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=23, column=0, sticky=W)
        oznaka_Rr2 = Label(f1_1, text='Rr2 =', font=('Times new roman', 11)).grid(row=23, column=2, sticky=W)
        vnos_Rr2 = Entry(f1_1, textvariable=Rr2, width=10, font=('Times new roman', 11))
        vnos_Rr2.grid(row=23, column=3, sticky=W)
        tip_Rr2 = Hovertip(vnos_Rr2, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=23, column=4, sticky=W)
        
        pomen_n2 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=24, column=0, sticky=W)
        oznaka_n2 = Label(f1_1, text='n2 =', font=('Times new roman', 11)).grid(row=24, column=2, sticky=W)
        vnos_n2 = Entry(f1_1, textvariable=n2, width=10, font=('Times new roman', 11)).grid(row=24, column=3, sticky=W)
        enota_n2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=24, column=4, sticky=W)
        
        pomen_M2_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=25, column=0, sticky=W)
        oznaka_M2_max = Label(f1_1, text='M2_max =', font=('Times new roman', 11)).grid(row=25, column=2, sticky=W)
        vnos_M2_max = Entry(f1_1, textvariable=M2_max, width=10, font=('Times new roman', 11))
        vnos_M2_max.grid(row=25, column=3, sticky=W)
        tip_M2_max = Hovertip(vnos_M2_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M2_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=25, column=4, sticky=W)
        
        Podatki_osi3 = Label(f1_1, text='PODATKI TRETJE OSI', font=('Times new roman', 12, 'bold')).grid(row=27, column=0, sticky=W)
        
        pomen_G3 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=28, column=0, sticky=W)
        oznaka_G3 = Label(f1_1, text='G3 =', font=('Times new roman', 11)).grid(row=28, column=2, sticky=W)
        vnos_G3 = Entry(f1_1, textvariable=G3, width=10, font=('Times new roman', 11))
        vnos_G3.grid(row=28, column=3, sticky=W)
        tip_G3 = Hovertip(vnos_G3, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G3 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=28, column=4, sticky=W)
        
        pomen_Rp3 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=29, column=0, sticky=W)
        oznaka_Rp3 = Label(f1_1, text='Rp3 =', font=('Times new roman', 11)).grid(row=29, column=2, sticky=W)
        vnos_Rp3 = Entry(f1_1, textvariable=Rp3, width=10, font=('Times new roman', 11)).grid(row=29, column=3, sticky=W)
        enota_Rp3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=29, column=4, sticky=W)
        
        pomen_BF3 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=30, column=0, sticky=W)
        oznaka_BF3 = Label(f1_1, text='BF3 =', font=('Times new roman', 11)).grid(row=30, column=2, sticky=W)
        vnos_BF3 = Entry(f1_1, textvariable=BF3, width=10, font=('Times new roman', 11))
        vnos_BF3.grid(row=30, column=3, sticky=W)
        tip_BF3 = Hovertip(vnos_BF3, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF3 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=30, column=4, sticky=W)
        
        pomen_Rr3 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=31, column=0, sticky=W)
        oznaka_Rr3 = Label(f1_1, text='Rr3 =', font=('Times new roman', 11)).grid(row=31, column=2, sticky=W)
        vnos_Rr3 = Entry(f1_1, textvariable=Rr3, width=10, font=('Times new roman', 11))
        vnos_Rr3.grid(row=31, column=3, sticky=W)
        tip_Rr3 = Hovertip(vnos_Rr3, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=31, column=4, sticky=W)
        
        pomen_n3 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=32, column=0, sticky=W)
        oznaka_n3 = Label(f1_1, text='n3 =', font=('Times new roman', 11)).grid(row=32, column=2, sticky=W)
        vnos_n3 = Entry(f1_1, textvariable=n3, width=10, font=('Times new roman', 11)).grid(row=32, column=3, sticky=W)
        enota_n3 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=32, column=4, sticky=W)
        
        pomen_M3_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=33, column=0, sticky=W)
        oznaka_M3_max = Label(f1_1, text='M3_max =', font=('Times new roman', 11)).grid(row=33, column=2, sticky=W)
        vnos_M3_max = Entry(f1_1, textvariable=M3_max, width=10, font=('Times new roman', 11))
        vnos_M3_max.grid(row=33, column=3, sticky=W)
        tip_M3_max = Hovertip(vnos_M3_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M3_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=33, column=4, sticky=W)
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[1] and dropdown3.get() == zavore[2]:
        for prostor in range(0,20):
            Label(f1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1, text='Razdalja os-vpenjalna naprava', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1, textvariable=L, width=10, font=('Times new roman', 11))
        vnos_L.grid(row=1, column=3, sticky=W)
        tip_L = Hovertip(vnos_L, 'Razdalja med osjo in vpenjalno napravo.')
        enota_L = Label(f1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1, textvariable=p, width=10, font=('Times new roman', 11))
        vnos_p.grid(row=3, column=3, sticky=W)
        tip_p = Hovertip(vnos_p, 'Delovni tlak v sprožilu zavore (ne sme presegati 115 bar).')
        enota_p = Label(f1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1, textvariable=p_max, width=10, font=('Times new roman', 11))
        vnos_p_max.grid(row=4, column=3, sticky=W)
        tip_p_max = Hovertip(vnos_p_max, 'Najvišji delovni tlak v sprožilu zavore (ne sme presegati 142 bar).')
        enota_p_max = Label(f1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_d = Label(f1, text='Premer batnice zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_d = Label(f1, text='d =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_d = Entry(f1, textvariable=d, width=10, font=('Times new roman', 11)).grid(row=5, column=3, sticky=W)
        enota_d = Label(f1, text='m', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_z_min = Label(f1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_z_min = Label(f1, text='z_min =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        enota_z_min = Label(f1, text='%', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1, textvariable=z_min, width=10, font=('Times new roman', 11))
            vnos_z_min.grid(row=6, column=3, sticky=W)
            tip_z_min = Hovertip(vnos_z_min, '''Velikost zavornega učinka za izbrano hitrost,
po Delegirani uredbi komisile (EU) 2015/68.''')
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_μ = Label(f1, text='μ =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        vnos_μ = Entry(f1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=7, column=3, sticky=W)
        enota_μ = Label(f1, text='/', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        pomen_R = Label(f1, text='Upor ceste', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_R = Label(f1, text='R =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_R = Entry(f1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_R = Label(f1, text='%', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1, text='PODATKI OSI', font=('Times new roman', 12, 'bold')).grid(row=10, column=0, sticky=W)
    
        pomen_G1 = Label(f1, text='Masa osi', font=('Times new roman', 11)).grid(row=11, column=0, sticky=W)
        oznaka_G1 = Label(f1, text='G1 =', font=('Times new roman', 11)).grid(row=11, column=2, sticky=W)
        vnos_G1 = Entry(f1, textvariable=G1, width=10, font=('Times new roman', 11))
        vnos_G1.grid(row=11, column=3, sticky=W)
        tip_G1 = Hovertip(vnos_G1, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G1 = Label(f1, text='kg', font=('Times new roman', 11)).grid(row=11, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_Rp1 = Label(f1, text='Rp1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_Rp1 = Entry(f1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=12, column=3, sticky=W)
        enota_Rp1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_BF1 = Label(f1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_BF1 = Label(f1, text='BF1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        vnos_BF1 = Entry(f1, textvariable=BF1, width=10, font=('Times new roman', 11))
        vnos_BF1.grid(row=13, column=3, sticky=W)
        tip_BF1 = Hovertip(vnos_BF1, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF1 = Label(f1, text='/', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_Rr1 = Label(f1, text='Rr1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_Rr1 = Entry(f1, textvariable=Rr1, width=10, font=('Times new roman', 11))
        vnos_Rr1.grid(row=14, column=3, sticky=W)
        tip_Rr1 = Hovertip(vnos_Rr1, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_n1 = Label(f1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_n1 = Label(f1, text='n1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_n1 = Entry(f1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=15, column=3, sticky=W)
        enota_n1 = Label(f1, text='/', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_M1_max = Label(f1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_M1_max = Label(f1, text='M1_max =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_M1_max = Entry(f1, textvariable=M1_max, width=10, font=('Times new roman', 11))
        vnos_M1_max.grid(row=16, column=3, sticky=W)
        tip_M1_max = Hovertip(vnos_M1_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M1_max = Label(f1, text='Nm', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)       
   
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[2] and dropdown3.get() == zavore[2]:
        
        f0_1 = Canvas(f1)
        f0_1.pack(side=LEFT, fill=BOTH, expand=1)
        f01_scrollbar = Scrollbar(f1, orient=VERTICAL, command=f0_1.yview)
        f01_scrollbar.pack(side=RIGHT, fill=Y)
        f0_1.configure(yscrollcommand=f01_scrollbar.set)
        f0_1.bind('<Configure>', lambda e: f0_1.configure(scrollregion=f0_1.bbox('all')))
        f1_1 = Frame(f0_1)
        f0_1.create_window((0,0), window=f1_1, anchor='nw')     
        
        for prostor in range(0,26):
            Label(f1_1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1_1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1_1, text='Medosna razdalja', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1_1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1_1, textvariable=L, width=10, font=('Times new roman', 11)).grid(row=1, column=3, sticky=W)
        enota_L = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1_1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1_1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1_1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1_1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1_1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1_1, textvariable=p, width=10, font=('Times new roman', 11))
        vnos_p.grid(row=3, column=3, sticky=W)
        tip_p = Hovertip(vnos_p, 'Delovni tlak v sprožilu zavore (ne sme presegati 115 bar).')
        enota_p = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1_1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1_1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1_1, textvariable=p_max, width=10, font=('Times new roman', 11))
        vnos_p_max.grid(row=4, column=3, sticky=W)
        tip_p_max = Hovertip(vnos_p_max, 'Najvišji delovni tlak v sprožilu zavore (ne sme presegati 142 bar).')
        enota_p_max = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_d = Label(f1_1, text='Premer batnice zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_d = Label(f1_1, text='d =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_d = Entry(f1_1, textvariable=d, width=10, font=('Times new roman', 11)).grid(row=5, column=3, sticky=W)
        enota_d = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_z_min = Label(f1_1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_z_min = Label(f1_1, text='z_min =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        enota_z_min = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1_1, textvariable=z_min, width=10, font=('Times new roman', 11))
            vnos_z_min.grid(row=6, column=3, sticky=W)
            tip_z_min = Hovertip(vnos_z_min, '''Velikost zavornega učinka za izbrano hitrost,
po Delegirani uredbi komisile (EU) 2015/68.''')
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1_1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_μ = Label(f1_1, text='μ =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        vnos_μ = Entry(f1_1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=7, column=3, sticky=W)
        enota_μ = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        pomen_R = Label(f1_1, text='Upor ceste', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_R = Label(f1_1, text='R =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_R = Entry(f1_1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_R = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1_1, text='PODATKI PRVE OSI', font=('Times new roman', 12, 'bold')).grid(row=10, column=0, sticky=W)
    
        pomen_G1 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=11, column=0, sticky=W)
        oznaka_G1 = Label(f1_1, text='G1 =', font=('Times new roman', 11)).grid(row=11, column=2, sticky=W)
        vnos_G1 = Entry(f1_1, textvariable=G1, width=10, font=('Times new roman', 11))
        vnos_G1.grid(row=11, column=3, sticky=W)
        tip_G1 = Hovertip(vnos_G1, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G1 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=11, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_Rp1 = Label(f1_1, text='Rp1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_Rp1 = Entry(f1_1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=12, column=3, sticky=W)
        enota_Rp1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_BF1 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_BF1 = Label(f1_1, text='BF1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        vnos_BF1 = Entry(f1_1, textvariable=BF1, width=10, font=('Times new roman', 11))
        vnos_BF1.grid(row=13, column=3, sticky=W)
        tip_BF1 = Hovertip(vnos_BF1, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_Rr1 = Label(f1_1, text='Rr1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_Rr1 = Entry(f1_1, textvariable=Rr1, width=10, font=('Times new roman', 11))
        vnos_Rr1.grid(row=14, column=3, sticky=W)
        tip_Rr1 = Hovertip(vnos_Rr1, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_n1 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_n1 = Label(f1_1, text='n1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_n1 = Entry(f1_1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=15, column=3, sticky=W)
        enota_n1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_M1_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_M1_max = Label(f1_1, text='M1_max =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_M1_max = Entry(f1_1, textvariable=M1_max, width=10, font=('Times new roman', 11))
        vnos_M1_max.grid(row=16, column=3, sticky=W)
        tip_M1_max = Hovertip(vnos_M1_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M1_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        Podatki_osi2 = Label(f1_1, text='PODATKI DRUGE OSI', font=('Times new roman', 12, 'bold')).grid(row=18, column=0, sticky=W)
        
        pomen_G2 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=19, column=0, sticky=W)
        oznaka_G2 = Label(f1_1, text='G2 =', font=('Times new roman', 11)).grid(row=19, column=2, sticky=W)
        vnos_G2 = Entry(f1_1, textvariable=G2, width=10, font=('Times new roman', 11))
        vnos_G2.grid(row=19, column=3, sticky=W)
        tip_G2 = Hovertip(vnos_G2, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G2 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=19, column=4, sticky=W)
        
        pomen_Rp2 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=20, column=0, sticky=W)
        oznaka_Rp2 = Label(f1_1, text='Rp2 =', font=('Times new roman', 11)).grid(row=20, column=2, sticky=W)
        vnos_Rp2 = Entry(f1_1, textvariable=Rp2, width=10, font=('Times new roman', 11)).grid(row=20, column=3, sticky=W)
        enota_Rp2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=20, column=4, sticky=W)
        
        pomen_BF2 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=21, column=0, sticky=W)
        oznaka_BF2 = Label(f1_1, text='BF2 =', font=('Times new roman', 11)).grid(row=21, column=2, sticky=W)
        vnos_BF2 = Entry(f1_1, textvariable=BF2, width=10, font=('Times new roman', 11))
        vnos_BF2.grid(row=21, column=3, sticky=W)
        tip_BF2 = Hovertip(vnos_BF2, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=21, column=4, sticky=W)
        
        pomen_Rr2 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=22, column=0, sticky=W)
        oznaka_Rr2 = Label(f1_1, text='Rr2 =', font=('Times new roman', 11)).grid(row=22, column=2, sticky=W)
        vnos_Rr2 = Entry(f1_1, textvariable=Rr2, width=10, font=('Times new roman', 11))
        vnos_Rr2.grid(row=22, column=3, sticky=W)
        tip_Rr2 = Hovertip(vnos_Rr2, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=22, column=4, sticky=W)
        
        pomen_n2 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=23, column=0, sticky=W)
        oznaka_n2 = Label(f1_1, text='n2 =', font=('Times new roman', 11)).grid(row=23, column=2, sticky=W)
        vnos_n2 = Entry(f1_1, textvariable=n2, width=10, font=('Times new roman', 11)).grid(row=23, column=3, sticky=W)
        enota_n2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=23, column=4, sticky=W)
        
        pomen_M2_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=24, column=0, sticky=W)
        oznaka_M2_max = Label(f1_1, text='M2_max =', font=('Times new roman', 11)).grid(row=24, column=2, sticky=W)
        vnos_M2_max = Entry(f1_1, textvariable=M2_max, width=10, font=('Times new roman', 11))
        vnos_M2_max.grid(row=24, column=3, sticky=W)
        tip_M2_max = Hovertip(vnos_M2_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M2_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=24, column=4, sticky=W)

    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[3] and dropdown3.get() == zavore[2]:
                
        f0_1 = Canvas(f1)
        f0_1.pack(side=LEFT, fill=BOTH, expand=1)
        f01_scrollbar = Scrollbar(f1, orient=VERTICAL, command=f0_1.yview)
        f01_scrollbar.pack(side=RIGHT, fill=Y)
        f0_1.configure(yscrollcommand=f01_scrollbar.set)
        f0_1.bind('<Configure>', lambda e: f0_1.configure(scrollregion=f0_1.bbox('all')))
        f1_1 = Frame(f0_1)
        f0_1.create_window((0,0), window=f1_1, anchor='nw')     

        for prostor in range(0,34):
            Label(f1_1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1_1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1_1, text='Medosna razdalja', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1_1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1_1, textvariable=L, width=10, font=('Times new roman', 11))
        vnos_L.grid(row=1, column=3, sticky=W)
        tip_L = Hovertip(vnos_L, 'Medosna razdalja med prvo in drugo osjo oziroma drugo in tretjo osjo.')
        enota_L = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1_1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1_1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1_1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1_1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1_1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1_1, textvariable=p, width=10, font=('Times new roman', 11))
        vnos_p.grid(row=3, column=3, sticky=W)
        tip_p = Hovertip(vnos_p, 'Delovni tlak v sprožilu zavore (ne sme presegati 115 bar).')
        enota_p = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1_1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1_1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1_1, textvariable=p_max, width=10, font=('Times new roman', 11))
        vnos_p_max.grid(row=4, column=3, sticky=W)
        tip_p_max = Hovertip(vnos_p_max, 'Najvišji delovni tlak v sprožilu zavore (ne sme presegati 142 bar).')
        enota_p_max = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_d = Label(f1_1, text='Premer batnice zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_d = Label(f1_1, text='d =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_d = Entry(f1_1, textvariable=d, width=10, font=('Times new roman', 11)).grid(row=5, column=3, sticky=W)
        enota_d = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_z_min = Label(f1_1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_z_min = Label(f1_1, text='z_min =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        enota_z_min = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1_1, textvariable=z_min, width=10, font=('Times new roman', 11))
            vnos_z_min.grid(row=6, column=3, sticky=W)
            tip_z_min = Hovertip(vnos_z_min, '''Velikost zavornega učinka za izbrano hitrost,
po Delegirani uredbi komisile (EU) 2015/68.''')
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1_1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_μ = Label(f1_1, text='μ =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        vnos_μ = Entry(f1_1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=7, column=3, sticky=W)
        enota_μ = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        pomen_R = Label(f1_1, text='Upor ceste', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_R = Label(f1_1, text='R =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_R = Entry(f1_1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_R = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1_1, text='PODATKI PRVE OSI', font=('Times new roman', 12, 'bold')).grid(row=10, column=0, sticky=W)
    
        pomen_G1 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=11, column=0, sticky=W)
        oznaka_G1 = Label(f1_1, text='G1 =', font=('Times new roman', 11)).grid(row=11, column=2, sticky=W)
        vnos_G1 = Entry(f1_1, textvariable=G1, width=10, font=('Times new roman', 11))
        vnos_G1.grid(row=11, column=3, sticky=W)
        tip_G1 = Hovertip(vnos_G1, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G1 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=11, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_Rp1 = Label(f1_1, text='Rp1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_Rp1 = Entry(f1_1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=12, column=3, sticky=W)
        enota_Rp1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_BF1 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_BF1 = Label(f1_1, text='BF1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        vnos_BF1 = Entry(f1_1, textvariable=BF1, width=10, font=('Times new roman', 11))
        vnos_BF1.grid(row=13, column=3, sticky=W)
        tip_BF1 = Hovertip(vnos_BF1, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_Rr1 = Label(f1_1, text='Rr1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_Rr1 = Entry(f1_1, textvariable=Rr1, width=10, font=('Times new roman', 11))
        vnos_Rr1.grid(row=14, column=3, sticky=W)
        tip_Rr1 = Hovertip(vnos_Rr1, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_n1 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_n1 = Label(f1_1, text='n1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_n1 = Entry(f1_1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=15, column=3, sticky=W)
        enota_n1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_M1_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_M1_max = Label(f1_1, text='M1_max =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_M1_max = Entry(f1_1, textvariable=M1_max, width=10, font=('Times new roman', 11))
        vnos_M1_max.grid(row=16, column=3, sticky=W)
        tip_M1_max = Hovertip(vnos_M1_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M1_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        Podatki_osi2 = Label(f1_1, text='PODATKI DRUGE OSI', font=('Times new roman', 12, 'bold')).grid(row=18, column=0, sticky=W)
        
        pomen_G2 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=19, column=0, sticky=W)
        oznaka_G2 = Label(f1_1, text='G2 =', font=('Times new roman', 11)).grid(row=19, column=2, sticky=W)
        vnos_G2 = Entry(f1_1, textvariable=G2, width=10, font=('Times new roman', 11))
        vnos_G2.grid(row=19, column=3, sticky=W)
        tip_G2 = Hovertip(vnos_G2, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G2 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=19, column=4, sticky=W)
        
        pomen_Rp2 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=20, column=0, sticky=W)
        oznaka_Rp2 = Label(f1_1, text='Rp2 =', font=('Times new roman', 11)).grid(row=20, column=2, sticky=W)
        vnos_Rp2 = Entry(f1_1, textvariable=Rp2, width=10, font=('Times new roman', 11)).grid(row=20, column=3, sticky=W)
        enota_Rp2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=20, column=4, sticky=W)
        
        pomen_BF2 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=21, column=0, sticky=W)
        oznaka_BF2 = Label(f1_1, text='BF2 =', font=('Times new roman', 11)).grid(row=21, column=2, sticky=W)
        vnos_BF2 = Entry(f1_1, textvariable=BF2, width=10, font=('Times new roman', 11))
        vnos_BF2.grid(row=21, column=3, sticky=W)
        tip_BF2 = Hovertip(vnos_BF2, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=21, column=4, sticky=W)
        
        pomen_Rr2 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=22, column=0, sticky=W)
        oznaka_Rr2 = Label(f1_1, text='Rr2 =', font=('Times new roman', 11)).grid(row=22, column=2, sticky=W)
        vnos_Rr2 = Entry(f1_1, textvariable=Rr2, width=10, font=('Times new roman', 11))
        vnos_Rr2.grid(row=22, column=3, sticky=W)
        tip_Rr2 = Hovertip(vnos_Rr2, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=22, column=4, sticky=W)
        
        pomen_n2 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=23, column=0, sticky=W)
        oznaka_n2 = Label(f1_1, text='n2 =', font=('Times new roman', 11)).grid(row=23, column=2, sticky=W)
        vnos_n2 = Entry(f1_1, textvariable=n2, width=10, font=('Times new roman', 11)).grid(row=23, column=3, sticky=W)
        enota_n2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=23, column=4, sticky=W)
        
        pomen_M2_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=24, column=0, sticky=W)
        oznaka_M2_max = Label(f1_1, text='M2_max =', font=('Times new roman', 11)).grid(row=24, column=2, sticky=W)
        vnos_M2_max = Entry(f1_1, textvariable=M2_max, width=10, font=('Times new roman', 11))
        vnos_M2_max.grid(row=24, column=3, sticky=W)
        tip_M2_max = Hovertip(vnos_M2_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M2_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=24, column=4, sticky=W)
        
        Podatki_osi3 = Label(f1_1, text='PODATKI TRETJE OSI', font=('Times new roman', 12, 'bold')).grid(row=26, column=0, sticky=W)
        
        pomen_G3 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=27, column=0, sticky=W)
        oznaka_G3 = Label(f1_1, text='G3 =', font=('Times new roman', 11)).grid(row=27, column=2, sticky=W)
        vnos_G3 = Entry(f1_1, textvariable=G3, width=10, font=('Times new roman', 11))
        vnos_G3.grid(row=27, column=3, sticky=W)
        tip_G3 = Hovertip(vnos_G3, '''Največja velikost mase prenesene na os, najdemo
jo v katalogu ali poročilu o preskusu osi.''')
        enota_G3 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=27, column=4, sticky=W)
        
        pomen_Rp3 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=28, column=0, sticky=W)
        oznaka_Rp3 = Label(f1_1, text='Rp3 =', font=('Times new roman', 11)).grid(row=28, column=2, sticky=W)
        vnos_Rp3 = Entry(f1_1, textvariable=Rp3, width=10, font=('Times new roman', 11)).grid(row=28, column=3, sticky=W)
        enota_Rp3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=28, column=4, sticky=W)
        
        pomen_BF3 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=29, column=0, sticky=W)
        oznaka_BF3 = Label(f1_1, text='BF3 =', font=('Times new roman', 11)).grid(row=29, column=2, sticky=W)
        vnos_BF3 = Entry(f1_1, textvariable=BF3, width=10, font=('Times new roman', 11))
        vnos_BF3.grid(row=29, column=3, sticky=W)
        tip_BF3 = Hovertip(vnos_BF3, '''Faktor zaviranja najdemo v poročilu o preskusu osi,
prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_BF3 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=29, column=4, sticky=W)
        
        pomen_Rr3 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=30, column=0, sticky=W)
        oznaka_Rr3 = Label(f1_1, text='Rr3 =', font=('Times new roman', 11)).grid(row=30, column=2, sticky=W)
        vnos_Rr3 = Entry(f1_1, textvariable=Rr3, width=10, font=('Times new roman', 11))
        vnos_Rr3.grid(row=30, column=3, sticky=W)
        tip_Rr3 = Hovertip(vnos_Rr3, 'Standardne velikosti 0,1m do 0,25m, s korakom 0,025m.')
        enota_Rr3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=30, column=4, sticky=W)
        
        pomen_n3 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=31, column=0, sticky=W)
        oznaka_n3 = Label(f1_1, text='n3 =', font=('Times new roman', 11)).grid(row=31, column=2, sticky=W)
        vnos_n3 = Entry(f1_1, textvariable=n3, width=10, font=('Times new roman', 11)).grid(row=31, column=3, sticky=W)
        enota_n3 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=31, column=4, sticky=W)
        
        pomen_M3_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=32, column=0, sticky=W)
        oznaka_M3_max = Label(f1_1, text='M3_max =', font=('Times new roman', 11)).grid(row=32, column=2, sticky=W)
        vnos_M3_max = Entry(f1_1, textvariable=M3_max, width=10, font=('Times new roman', 11))
        vnos_M3_max.grid(row=32, column=3, sticky=W)
        tip_M3_max = Hovertip(vnos_M3_max, '''Največji dovoljen zavorni moment najdemo v poročilu o preskusu
osi, prejmemo ga ob naročilu osi s strani dobavitelja.''')
        enota_M3_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=32, column=4, sticky=W)
  


        

def Izbris_rezultatov():
    '''Funkcija izbriše prikazane rezultate'''
    Izpis.delete('1.0', END)




'''Izbira vrste priklopnika'''
dropdown1 = ttk.Combobox(f0, value=priklopnik, width = 22, font=('Times new roman', 11))
dropdown1.current(0) # Izberemo kater element combobox prikaže
dropdown1.place(x=5, y=0)    
dropdown1.bind('<<ComboboxSelected>>', Vrsta_priklopnika)

dropdown2 = ttk.Combobox(f0, value=os, width = 22, font=('Times new roman', 11))
dropdown2.current(0)
dropdown2.place(x=5, y=25)
dropdown2.bind('<<ComboboxSelected>>', Vrsta_priklopnika)

dropdown3 = ttk.Combobox(f0, value=zavore, width = 22, font=('Times new roman', 11))
dropdown3.current(0)
dropdown3.place(x=5, y=50)
dropdown3.bind('<<ComboboxSelected>>', Vrsta_priklopnika)

dropdown4 = ttk.Combobox(f0, value=hitrost, width = 22, font=('Times new roman', 11))
dropdown4.current(0)
dropdown4.place(x=5, y=75)
dropdown4_Label = Label(f0, text='km/h', font=('Times new roman', 11)).place(x=190, y=80)
dropdown4.bind('<<ComboboxSelected>>', Vrsta_priklopnika)




'''Gumbi'''       
Izracunaj = Button(f0, text='Izračunaj', width=10, 
                   command=Enacbe, font=('Times new roman', 11))
Izracunaj.place(x=300, y=50)
tip_Izracunaj = Hovertip(Izracunaj, 'Gumb zažene postopek računanja.')

Resetiraj = Button(f0, text='Izbriši rezultate', width=15, 
                   command=Izbris_rezultatov, font=('Times new roman', 11))
Resetiraj.place(x=400, y=50)
tip_Resetiraj = Hovertip(Resetiraj, 'Gumb izbriše izpisane rezultate.')




root.mainloop() # Ustvariti moramo zanko, ki poganja program
