# %%
import numpy as np
from tkinter import * # tkinter je modul znotraj Pythona, * pomeni da uvozimo cel modul. 
# Tkinter je modul, kjer lahko definiramo okna, znotraj oken pa gumbe,...
from tkinter import ttk # moraš dodatno uvozt??????
root = Tk() # Tk je modul znotraj tkintera. Ustvarimo okno (odzadje)
root.title('Programsko orodje za preverjanje zavornega učinka priklopnih vozil') # Definiramo naslov programa


#root.iconbitmap('C:/Users/Urban/Documents/2021 April -/Fakulteta/Diploma_dok/Program/Priklopnik.ico') # Uvozimo ikono v program.
# Niz (string) je lokacija, kjer se nahaja ikona(slika)
root.geometry('1300x700') # Definiramo kako veliko okno (odzadje) želimo




'''Okvirji'''
CelotenOkvir = Frame(root, relief=RIDGE,bd=5)
CelotenOkvir.pack(fill=BOTH, expand=1) 

LeviOkvir = Frame(CelotenOkvir, relief=RIDGE, bd=5)
LeviOkvir.pack(side=LEFT, fill=BOTH, expand=1)

DesniOkvir = Frame(CelotenOkvir, relief=RIDGE, bd=5)
DesniOkvir.pack(side=RIGHT, fill=BOTH, expand=1)


f0 = Frame(LeviOkvir, width=600, height=150, relief=RIDGE, bd=5)
f0.pack(side=TOP, fill=BOTH)

f1 = Frame(LeviOkvir, relief=RIDGE, bd=5)
f1.pack(fill=BOTH, expand=1)

f2 = Frame(DesniOkvir, relief=RIDGE, bd=5)
f2.pack(fill=BOTH, expand=1)



''' Okno za izpis rezultatov '''
Izpis_Scroll = Scrollbar(f2)
Izpis_Scroll.pack(side=RIGHT, fill=Y)

Izpis = Text(f2, font=('Times new roman', 11), yscrollcommand=Izpis_Scroll.set)
Izpis.pack(fill=BOTH, expand=1)
Izpis_Scroll.configure(command=Izpis.yview)



'''Podatki za vrsto preračuna'''
# Vrste zavor za preračun
priklopnik = [
    'Izberi vrsto priklopnika',
    'Priklopnik s centralno osjo',
]


# Število osi
os = [
    'Izberi število osi',
    'Ena os',
    'Dve osi',
    'Tri osi'
]


# Vrsa zavor
zavore = [
    'Izberi tip zavor',
    'Pnevmatične zavore',
    'Hidravlične zavore'
]


# Hitrosti
hitrost = [
    'Izberi hitrost',
    '25',
    '40',
    '50',
    '60',
    '80'
]

# Tipske velikosti radijev zavornega bobna
Radij_bobna = [
    'Izberi radij',
    '0.07',
    '0.1',
    '0.125',
    '0.15',
    '0.175',
    '0.2',
    '0.203',
    '0.21',
    '0.26'
]

# Minimalni zavorni učinek po predpisih
Predpisi_z = ['35', '50']




'''Funckije'''
#Vhodni parmetri
L = StringVar()
h = StringVar()
p = StringVar()
p_max = StringVar()
pI = StringVar()
pII = StringVar()
d = StringVar()
z_min = StringVar()
μ = StringVar()
R = StringVar()
BF1 = StringVar()
BF2 = StringVar()
BF3 = StringVar()
G1 = StringVar()
G2 = StringVar()
G3 = StringVar()
Rp1 = StringVar()
Rp2 = StringVar()
Rp3 = StringVar()
Rb1= StringVar()
Rb2= StringVar()
Rb3= StringVar()
Rr1 = StringVar()
Rr2 = StringVar()
Rr3 = StringVar()
Ro1 = StringVar()
Ro2 = StringVar()
Ro3 = StringVar()
n1 = StringVar()
n2 = StringVar()
n3 = StringVar()
M1_max = StringVar()
M2_max = StringVar()
M3_max = StringVar()
#Izračunani parametri
txt_M1_z = StringVar()
txt_M2_z = StringVar()
txt_M3_z = StringVar()
txt_M_cel = StringVar()
txt_zav_uc = StringVar()
txt_F_pr = StringVar()
txt_F_vo = StringVar()
txt_N1 = StringVar()
txt_N2 = StringVar()
txt_N3 = StringVar()
txt_z_N1 = StringVar()
txt_z_N2 = StringVar()
txt_z_N3 = StringVar()
txt_M1_mog = StringVar()
txt_M2_mog = StringVar()
txt_M3_mog = StringVar()
txt_μ = StringVar()




def Enacbe():
    '''Funkcija sprejme nize parametrov, ki jih vnesemo
    v program, jih pretvori v decimalno število in
    na koncu izpiše rezultate izračunanih parametrov v nizih.'''
    #Parametri potrebni za izračun
    g = 9.81 # [m/s^2]
    
    if dropdown1.get() == priklopnik[1] and dropdown2.get() == os[1] and dropdown3.get() == zavore[1]: # .get() funckcija uporabi kar vpišemo v polje
        f_p = float(p.get()) 
        f_pI = float(pI.get())
        f_pII = float(pII.get())
        f_BF1 = float(BF1.get())
        f_Rr1 = float(Rr1.get())
        f_n1 = float(n1.get())
        f_R = float(R.get())
        f_G1 = float(G1.get())
        f_Rp1 = float(Rp1.get())
        f_h = float(h.get())
        f_L = float(L.get())
        f_p_max = float(p_max.get())
        f_μ = float(μ.get())

        M1_z = (f_pI*f_p-f_pII) * f_Rr1* f_BF1 * f_n1
        str_M1_z = str('%.2f' % ((M1_z)))
        txt_M1_z.set(str_M1_z)
        
        zav_uc = (M1_z * (100-f_R)/(f_G1 * g * f_Rp1))
        str_zav_uc = str('%.2f' % ((zav_uc)))
        txt_zav_uc.set(str_zav_uc)
        
        F_pr = (f_G1 * g * 13.5 * f_h / (100 * f_L))
        str_F_pr = str('%.2f' % ((F_pr)))
        txt_F_pr.set(str_F_pr)
        
        F_vo = (F_pr)
        str_F_vo = str('%.2f' % ((F_vo)))
        txt_F_vo.set(str_F_vo)
        
        N1 = (f_G1*g - F_pr)
        str_N1 = str('%.2f' % ((N1)))
        txt_N1.set(str_N1)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        str_z_N1 = str('%.2f' % ((z_N1)))
        txt_z_N1.set(str_z_N1)
        
        M1_mog = (f_pI*f_p_max-f_pII) * f_Rr1* f_BF1 * f_n1
        str_M1_mog = str('%.2f' % ((M1_mog)))
        txt_M1_mog.set(str_M1_mog)
        
        μ_ = (f_μ*100)
        str_μ = str('%.2f' % ((μ_)))
        txt_μ.set(str_μ)

        Izpis.insert(END, '1 - Zavorni moment \n M1_z = (pI*p-pII) * Rr1 * BF1 * n1  \t\t\t\t\t = \t'+txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Teoretični zavorni učinek \n z = M1_z * (100-R) / (G1 * g * Rp1)  \t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 3 - Dinamična preobremenitev \n F_pr = G1 * g * 13.5 * h / (100 * L)  \t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 4 - Dinamična obremenitev vlečnega ojesa \n N_vo = F_pr  \t\t\t\t\t = \t'
                     +txt_F_vo.get()+' N')
        Izpis.insert(END, '\n\n 5 - Dinamična obremenitev osi \n N1 = G1 * g - F_pr  \t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 6 - Dinamični zavorni izkoristek osi \n z_N1 = M1_z * (100-R) / (N1 * Rp)   \t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 7 - Največji mogoč zavorni moment \n M1_mog = (pI*p_max-pII) * Rr1 * BF1 * n1 \t\t=       \t\t\t\t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 8 - Zdrs osi \n z_N1   ≤   μ * 100     \t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[2] and dropdown3.get() == zavore[1]:
        f_p = float(p.get()) 
        f_pI = float(pI.get())
        f_pII = float(pII.get())
        f_BF1 = float(BF1.get())
        f_BF2 = float(BF2.get())
        f_Rr1 = float(Rr1.get())
        f_Rr2 = float(Rr2.get())
        f_n1 = float(n1.get())
        f_n2 = float(n2.get())
        f_R = float(R.get())
        f_G1 = float(G1.get())
        f_G2 = float(G2.get())
        f_Rp1 = float(Rp1.get())
        f_Rp2 = float(Rp2.get())
        f_h = float(h.get())
        f_L = float(L.get())
        f_p_max = float(p_max.get())
        f_μ = float(μ.get())

        M1_z = (f_pI*f_p-f_pII) * f_Rr1* f_BF1 * f_n1
        str_M1_z = str('%.2f' % ((M1_z)))
        txt_M1_z.set(str_M1_z)
        
        M2_z = (f_pI*f_p-f_pII) * f_Rr2* f_BF2 * f_n2
        str_M2_z = str('%.2f' % ((M2_z)))
        txt_M2_z.set(str_M2_z)
        
        M_cel = (M1_z + M2_z)
        str_M_cel = str('%.2f' % ((M_cel)))
        txt_M_cel.set(str_M_cel)
        
        zav_uc = (M_cel * (100-f_R)/(f_G1 * g * f_Rp1 + f_G2 * g * f_Rp2))
        str_zav_uc = str('%.2f' % ((zav_uc)))
        txt_zav_uc.set(str_zav_uc)      
        
        F_pr = ((f_G1+f_G2) * g * 13.5 * f_h / (100 * f_L))
        str_F_pr = str('%.2f' % ((F_pr)))
        txt_F_pr.set(str_F_pr)
        
        N1 = (f_G1*g + F_pr)
        str_N1 = str('%.2f' % ((N1)))
        txt_N1.set(str_N1)
        
        N2 = (f_G2*g - F_pr)
        str_N2 = str('%.2f' % ((N2)))
        txt_N2.set(str_N2)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        str_z_N1 = str('%.2f' % ((z_N1)))
        txt_z_N1.set(str_z_N1)
        
        z_N2 = (M2_z * (100-f_R) /(N2 * f_Rp2))
        str_z_N2 = str('%.2f' % ((z_N2)))
        txt_z_N2.set(str_z_N2)
        
        M1_mog = (f_pI*f_p_max-f_pII) * f_Rr1* f_BF1 * f_n1
        str_M1_mog = str('%.2f' % ((M1_mog)))
        txt_M1_mog.set(str_M1_mog)
        
        M2_mog = (f_pI*f_p_max-f_pII) * f_Rr2* f_BF2 * f_n2
        str_M2_mog = str('%.2f' % ((M2_mog)))
        txt_M2_mog.set(str_M2_mog)
        
        μ_ = (f_μ*100)
        str_μ = str('%.2f' % ((μ_)))
        txt_μ.set(str_μ)

        Izpis.insert(END, '1 - Zavorni moment prve osi \n M1_z = (pI*p-pII) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t = \t'
                     +txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Zavorni moment druge osi \n M2_z = (pI*p-pII) * Rr2 * BF2 * n2  \t\t\t\t\t\t\t = \t'
                     +txt_M2_z.get()+' Nm')
        Izpis.insert(END, '\n\n 3 - Celoten zavorni moment \n M_cel = M1_z + M2_z     \t\t\t\t\t\t\t = \t'+txt_M_cel.get()+' Nm')      
        Izpis.insert(END, '\n\n 4 - Teoretični zavorni učinek \n z = M_cel * (100-R)/(G1 * g * Rp1 + G2 * g * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 5 - Dinamična preobremenitev \n F_pr = (G1+G2) * g * 13.5 * h / (100 * L)  \t\t\t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 6 - Dinamična obremenitev prve osi \n N1 = G1 * g + F_pr  \t\t\t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 7 - Dinamična obremenitev druge osi \n N2 = G2 * g - F_pr \t\t\t\t\t\t\t = \t'+txt_N2.get()+' N')
        Izpis.insert(END, '\n\n 8 - Dinamični zavorni izkoristek prve osi \n z_N1 = M1_z * (100-R) / (N1 * Rp1)   \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 9 - Dinamični zavorni izkoristek druge osi \n z_N2 = M2_z * (100-R) / (N2 * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' %')        
        Izpis.insert(END, '\n\n 10 - Največji mogoč zavorni moment prve osi \n M1_mog = (pI*p_max-pII) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t=       \t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 11 - Največji mogoč zavorni moment druge osi \n M2_mog = (pI*p_max-pII) * Rr2 * BF2 * n2 \t\t\t\t\t\t\t=       \t'
                     +txt_M2_mog.get()+' Nm \t ≤   '+M2_max.get()+' Nm')
        Izpis.insert(END, '\n\n 12 - Zdrs prve osi \n z_N1   ≤   μ * 100     \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 13 - Zdrs druge osi \n z_N2   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' % \t ≤   '+txt_μ.get()+' %')
    
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[3]  and dropdown3.get() == zavore[1]:     
        f_p = float(p.get()) 
        f_pI = float(pI.get())
        f_pII = float(pII.get())
        f_BF1 = float(BF1.get())
        f_BF2 = float(BF2.get())
        f_BF3 = float(BF3.get())
        f_Rr1 = float(Rr1.get())
        f_Rr2 = float(Rr2.get())
        f_Rr3 = float(Rr3.get())
        f_n1 = float(n1.get())
        f_n2 = float(n2.get())
        f_n3 = float(n3.get())
        f_R = float(R.get())
        f_G1 = float(G1.get())
        f_G2 = float(G2.get())
        f_G3 = float(G3.get())
        f_Rp1 = float(Rp1.get())
        f_Rp2 = float(Rp2.get())
        f_Rp3 = float(Rp3.get())
        f_h = float(h.get())
        f_L = float(L.get())
        f_p_max = float(p_max.get())
        f_μ = float(μ.get())

        M1_z = (f_pI*f_p-f_pII) * f_Rr1* f_BF1 * f_n1
        str_M1_z = str('%.2f' % ((M1_z)))
        txt_M1_z.set(str_M1_z)
        
        M2_z = (f_pI*f_p-f_pII) * f_Rr2* f_BF2 * f_n2
        str_M2_z = str('%.2f' % ((M2_z)))
        txt_M2_z.set(str_M2_z)
        
        M3_z = (f_pI*f_p-f_pII) * f_Rr3* f_BF3 * f_n3
        str_M3_z = str('%.2f' % ((M3_z)))
        txt_M3_z.set(str_M3_z)
        
        M_cel = (M1_z + M2_z + M3_z)
        str_M_cel = str('%.2f' % ((M_cel)))
        txt_M_cel.set(str_M_cel)
        
        zav_uc = (M_cel * (100-f_R)/(f_G1 * g * f_Rp1 + f_G2 * g * f_Rp2 + f_G3 * g * f_Rp3))
        str_zav_uc = str('%.2f' % ((zav_uc)))
        txt_zav_uc.set(str_zav_uc)      
        
        F_pr = ((f_G1+f_G2+f_G3) * g * 13.5 * f_h / (100 * f_L))
        str_F_pr = str('%.2f' % ((F_pr)))
        txt_F_pr.set(str_F_pr)
        
        N1 = (f_G1*g + F_pr)
        str_N1 = str('%.2f' % ((N1)))
        txt_N1.set(str_N1)
        
        N2 = (f_G2*g)
        str_N2 = str('%.2f' % ((N2)))
        txt_N2.set(str_N2)
        
        N3 = (f_G3*g - F_pr)
        str_N3 = str('%.2f' % ((N3)))
        txt_N3.set(str_N3)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        str_z_N1 = str('%.2f' % ((z_N1)))
        txt_z_N1.set(str_z_N1)
        
        z_N2 = (M2_z * (100-f_R) /(N2 * f_Rp2))
        str_z_N2 = str('%.2f' % ((z_N2)))
        txt_z_N2.set(str_z_N2)
        
        z_N3 = (M3_z * (100-f_R) /(N3 * f_Rp3))
        str_z_N3 = str('%.2f' % ((z_N3)))
        txt_z_N3.set(str_z_N3)
        
        M1_mog = (f_pI*f_p_max-f_pII) * f_Rr1* f_BF1 * f_n1
        str_M1_mog = str('%.2f' % ((M1_mog)))
        txt_M1_mog.set(str_M1_mog)
        
        M2_mog = (f_pI*f_p_max-f_pII) * f_Rr2* f_BF2 * f_n2
        str_M2_mog = str('%.2f' % ((M2_mog)))
        txt_M2_mog.set(str_M2_mog)
        
        M3_mog = (f_pI*f_p_max-f_pII) * f_Rr3* f_BF3 * f_n3
        str_M3_mog = str('%.2f' % ((M3_mog)))
        txt_M3_mog.set(str_M3_mog)
        
        μ_ = (f_μ*100)
        str_μ = str('%.2f' % ((μ_)))
        txt_μ.set(str_μ)

        Izpis.insert(END, '1 - Zavorni moment prve osi \n M1_z = (pI*p-pII) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t = \t'
                     +txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Zavorni moment druge osi \n M2_z = (pI*p-pII) * Rr2 * BF2 * n2  \t\t\t\t\t\t\t = \t'
                     +txt_M2_z.get()+' Nm')
        Izpis.insert(END, '\n\n 3 - Zavorni moment tretje osi \n M3_z = (pI*p-pII) * Rr3 * BF3 * n3  \t\t\t\t\t\t\t = \t'
                     +txt_M3_z.get()+' Nm')
        Izpis.insert(END, '\n\n 4 - Celoten zavorni moment \n M_cel = M1_z + M2_z + M3_z    \t\t\t\t\t\t\t = \t'+txt_M_cel.get()+' Nm')      
        Izpis.insert(END, '\n\n 5 - Teoretični zavorni učinek \n z = M_cel * (100-R)/(G1 * g * Rp1 + G2 * g * Rp2 + G3 * g * Rp3)  \t\t\t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 6 - Dinamična preobremenitev \n F_pr = (G1+G2+G3) * g * 13.5 * h / (100 * L)  \t\t\t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 7 - Dinamična obremenitev prve osi \n N1 = G1 * g + F_pr  \t\t\t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 8 - Dinamična obremenitev druge osi \n N2 = G2 * g \t\t\t\t\t\t\t = \t'+txt_N2.get()+' N')
        Izpis.insert(END, '\n\n 9 - Dinamična obremenitev tretje osi \n N3 = G3 * g - F_pr \t\t\t\t\t\t\t = \t'+txt_N3.get()+' N')
        Izpis.insert(END, '\n\n 10 - Dinamični zavorni izkoristek prve osi \n z_N1 = M1_z * (100-R) / (N1 * Rp1)   \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 11 - Dinamični zavorni izkoristek druge osi \n z_N2 = M2_z * (100-R) / (N2 * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' %')        
        Izpis.insert(END, '\n\n 12 - Dinamični zavorni izkoristek tretje osi \n z_N3 = M3_z * (100-R) / (N3 * Rp3)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N3.get()+' %')
        Izpis.insert(END, '\n\n 13 - Največji mogoč zavorni moment prve osi \n M1_mog = (pI*p_max-pII) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t=       \t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 14 - Največji mogoč zavorni moment druge osi \n M2_mog = (pI*p_max-pII) * Rr2 * BF2 * n2 \t\t\t\t\t\t\t=       \t'
                     +txt_M2_mog.get()+' Nm \t ≤   '+M2_max.get()+' Nm')
        Izpis.insert(END, '\n\n 15 - Največji mogoč zavorni moment tretje osi \n M3_mog = (pI*p_max-pII) * Rr3 * BF3 * n3 \t\t\t\t\t\t\t=       \t'
                     +txt_M3_mog.get()+' Nm \t ≤   '+M3_max.get()+' Nm')
        Izpis.insert(END, '\n\n 16 - Zdrs prve osi \n z_N1   ≤   μ * 100     \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 17 - Zdrs druge osi \n z_N2   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 18 - Zdrs tretje osi \n z_N2   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N3.get()+' % \t ≤   '+txt_μ.get()+' %')
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[1] and dropdown3.get() == zavore[2]:
        f_p = float(p.get()) 
        f_d = float(d.get())
        f_BF1 = float(BF1.get())
        f_Rr1 = float(Rr1.get())
        f_n1 = float(n1.get())
        f_R = float(R.get())
        f_G1 = float(G1.get())
        f_Rp1 = float(Rp1.get())
        f_h = float(h.get())
        f_L = float(L.get())
        f_p_max = float(p_max.get())
        f_μ = float(μ.get())

        M1_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        str_M1_z = str('%.2f' % ((M1_z)))
        txt_M1_z.set(str_M1_z)
        
        zav_uc = (M1_z * (100-f_R)/(f_G1 * g * f_Rp1))
        str_zav_uc = str('%.2f' % ((zav_uc)))
        txt_zav_uc.set(str_zav_uc)
        
        F_pr = (f_G1 * g * 13.5 * f_h / (100 * f_L))
        str_F_pr = str('%.2f' % ((F_pr)))
        txt_F_pr.set(str_F_pr)
        
        F_vo = (F_pr)
        str_F_vo = str('%.2f' % ((F_vo)))
        txt_F_vo.set(str_F_vo)
        
        N1 = (f_G1*g - F_pr)
        str_N1 = str('%.2f' % ((N1)))
        txt_N1.set(str_N1)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        str_z_N1 = str('%.2f' % ((z_N1)))
        txt_z_N1.set(str_z_N1)
        
        M1_mog = ((f_p_max*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        str_M1_mog = str('%.2f' % ((M1_mog)))
        txt_M1_mog.set(str_M1_mog)
        
        μ_ = (f_μ*100)
        str_μ = str('%.2f' % ((μ_)))
        txt_μ.set(str_μ)

        Izpis.insert(END, '1 - Zavorni moment \n M1_z = (p * (π*d^2/4)) * Rr1 * BF1 * n1  \t\t\t\t\t = \t'+txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Teoretični zavorni učinek \n z = M1_z * (100-R) / (G1 * g * Rp1)  \t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 3 - Dinamična preobremenitev \n F_pr = G1 * g * 13.5 * h / (100 * L)  \t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 4 - Dinamična obremenitev vlečnega ojesa \n N_vo = F_pr  \t\t\t\t\t = \t'
                     +txt_F_vo.get()+' N')
        Izpis.insert(END, '\n\n 5 - Dinamična obremenitev osi \n N1 = G1 * g - F_pr  \t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 6 - Dinamični zavorni izkoristek osi \n z_N1 = M1_z * (100-R) / (N1 * Rp)   \t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 7 - Največji mogoč zavorni moment \n M1_mog = (p_max * (π*d^2/4)) * Rr1 * BF1 * n1 \t\t=       \t\t\t\t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 8 - Zdrs osi \n z_N1   ≤   μ * 100     \t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[2] and dropdown3.get() == zavore[2]:
        f_p = float(p.get()) 
        f_d = float(d.get())
        f_BF1 = float(BF1.get())
        f_BF2 = float(BF2.get())
        f_Rr1 = float(Rr1.get())
        f_Rr2 = float(Rr2.get())
        f_n1 = float(n1.get())
        f_n2 = float(n2.get())
        f_R = float(R.get())
        f_G1 = float(G1.get())
        f_G2 = float(G2.get())
        f_Rp1 = float(Rp1.get())
        f_Rp2 = float(Rp2.get())
        f_h = float(h.get())
        f_L = float(L.get())
        f_p_max = float(p_max.get())
        f_μ = float(μ.get())

        M1_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        str_M1_z = str('%.2f' % ((M1_z)))
        txt_M1_z.set(str_M1_z)
        
        M2_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr2* f_BF2 * f_n2)
        str_M2_z = str('%.2f' % ((M2_z)))
        txt_M2_z.set(str_M2_z)
        
        M_cel = (M1_z + M2_z)
        str_M_cel = str('%.2f' % ((M_cel)))
        txt_M_cel.set(str_M_cel)
        
        zav_uc = (M_cel * (100-f_R)/(f_G1 * g * f_Rp1 + f_G2 * g * f_Rp2))
        str_zav_uc = str('%.2f' % ((zav_uc)))
        txt_zav_uc.set(str_zav_uc)      
        
        F_pr = ((f_G1+f_G2) * g * 13.5 * f_h / (100 * f_L))
        str_F_pr = str('%.2f' % ((F_pr)))
        txt_F_pr.set(str_F_pr)
        
        N1 = (f_G1*g + F_pr)
        str_N1 = str('%.2f' % ((N1)))
        txt_N1.set(str_N1)
        
        N2 = (f_G2*g - F_pr)
        str_N2 = str('%.2f' % ((N2)))
        txt_N2.set(str_N2)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        str_z_N1 = str('%.2f' % ((z_N1)))
        txt_z_N1.set(str_z_N1)
        
        z_N2 = (M2_z * (100-f_R) /(N2 * f_Rp2))
        str_z_N2 = str('%.2f' % ((z_N2)))
        txt_z_N2.set(str_z_N2)
        
        M1_mog = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        str_M1_mog = str('%.2f' % ((M1_mog)))
        txt_M1_mog.set(str_M1_mog)
        
        M2_mog = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr2* f_BF2 * f_n2)
        str_M2_mog = str('%.2f' % ((M2_mog)))
        txt_M2_mog.set(str_M2_mog)
        
        μ_ = (f_μ*100)
        str_μ = str('%.2f' % ((μ_)))
        txt_μ.set(str_μ)

        Izpis.insert(END, '1 - Zavorni moment prve osi \n M1_z = (p * (π*d^2/4)) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t = \t'
                     +txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Zavorni moment druge osi \n M2_z = (p * (π*d^2/4)) * Rr2 * BF2 * n2  \t\t\t\t\t\t\t = \t'
                     +txt_M2_z.get()+' Nm')
        Izpis.insert(END, '\n\n 3 - Celoten zavorni moment \n M_cel = M1_z + M2_z     \t\t\t\t\t\t\t = \t'+txt_M_cel.get()+' Nm')      
        Izpis.insert(END, '\n\n 4 - Teoretični zavorni učinek \n z = M_cel * (100-R)/(G1 * g * Rp1 + G2 * g * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 5 - Dinamična preobremenitev \n F_pr = (G1+G2) * g * 13.5 * h / (100 * L)  \t\t\t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 6 - Dinamična obremenitev prve osi \n N1 = G1 * g + F_pr  \t\t\t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 7 - Dinamična obremenitev druge osi \n N2 = G2 * g - F_pr \t\t\t\t\t\t\t = \t'+txt_N2.get()+' N')
        Izpis.insert(END, '\n\n 8 - Dinamični zavorni izkoristek prve osi \n z_N1 = M1_z * (100-R) / (N1 * Rp1)   \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 9 - Dinamični zavorni izkoristek druge osi \n z_N2 = M2_z * (100-R) / (N2 * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' %')        
        Izpis.insert(END, '\n\n 10 - Največji mogoč zavorni moment prve osi \n M1_mog = (p_max * (π*d^2/4)) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t=       \t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 11 - Največji mogoč zavorni moment druge osi \n M2_mog = (p_max * (π*d^2/4)) * Rr2 * BF2 * n2 \t\t\t\t\t\t\t=       \t'
                     +txt_M2_mog.get()+' Nm \t ≤   '+M2_max.get()+' Nm')
        Izpis.insert(END, '\n\n 12 - Zdrs prve osi \n z_N1   ≤   μ * 100     \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 13 - Zdrs druge osi \n z_N2   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' % \t ≤   '+txt_μ.get()+' %')
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[3] and dropdown3.get() == zavore[2]:
        f_p = float(p.get()) 
        f_d = float(d.get())
        f_BF1 = float(BF1.get())
        f_BF2 = float(BF2.get())
        f_BF3 = float(BF3.get())
        f_Rr1 = float(Rr1.get())
        f_Rr2 = float(Rr2.get())
        f_Rr3 = float(Rr3.get())
        f_n1 = float(n1.get())
        f_n2 = float(n2.get())
        f_n3 = float(n3.get())
        f_R = float(R.get())
        f_G1 = float(G1.get())
        f_G2 = float(G2.get())
        f_G3 = float(G3.get())
        f_Rp1 = float(Rp1.get())
        f_Rp2 = float(Rp2.get())
        f_Rp3 = float(Rp3.get())
        f_h = float(h.get())
        f_L = float(L.get())
        f_p_max = float(p_max.get())
        f_μ = float(μ.get())

        M1_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        str_M1_z = str('%.2f' % ((M1_z)))
        txt_M1_z.set(str_M1_z)
        
        M2_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr2* f_BF2 * f_n2)
        str_M2_z = str('%.2f' % ((M2_z)))
        txt_M2_z.set(str_M2_z)
        
        M3_z = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr3* f_BF3 * f_n3)
        str_M3_z = str('%.2f' % ((M3_z)))
        txt_M3_z.set(str_M3_z)
        
        M_cel = (M1_z + M2_z + M3_z)
        str_M_cel = str('%.2f' % ((M_cel)))
        txt_M_cel.set(str_M_cel)
        
        zav_uc = (M_cel * (100-f_R)/(f_G1 * g * f_Rp1 + f_G2 * g * f_Rp2 + f_G3 * g * f_Rp3))
        str_zav_uc = str('%.2f' % ((zav_uc)))
        txt_zav_uc.set(str_zav_uc)      
        
        F_pr = ((f_G1+f_G2+f_G3) * g * 13.5 * f_h / (100 * f_L))
        str_F_pr = str('%.2f' % ((F_pr)))
        txt_F_pr.set(str_F_pr)
        
        N1 = (f_G1*g + F_pr)
        str_N1 = str('%.2f' % ((N1)))
        txt_N1.set(str_N1)
        
        N2 = (f_G2*g)
        str_N2 = str('%.2f' % ((N2)))
        txt_N2.set(str_N2)
        
        N3 = (f_G3*g - F_pr)
        str_N3 = str('%.2f' % ((N3)))
        txt_N3.set(str_N3)
        
        z_N1 = (M1_z * (100-f_R) /(N1 * f_Rp1))
        str_z_N1 = str('%.2f' % ((z_N1)))
        txt_z_N1.set(str_z_N1)
        
        z_N2 = (M2_z * (100-f_R) /(N2 * f_Rp2))
        str_z_N2 = str('%.2f' % ((z_N2)))
        txt_z_N2.set(str_z_N2)
        
        z_N3 = (M3_z * (100-f_R) /(N3 * f_Rp3))
        str_z_N3 = str('%.2f' % ((z_N3)))
        txt_z_N3.set(str_z_N3)
        
        M1_mog = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr1* f_BF1 * f_n1)
        str_M1_mog = str('%.2f' % ((M1_mog)))
        txt_M1_mog.set(str_M1_mog)
        
        M2_mog = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr2* f_BF2 * f_n2)
        str_M2_mog = str('%.2f' % ((M2_mog)))
        txt_M2_mog.set(str_M2_mog)
        
        M3_mog = ((f_p*(10**5) * (np.pi*f_d**2/4)) * f_Rr3* f_BF3 * f_n3)
        str_M3_mog = str('%.2f' % ((M3_mog)))
        txt_M3_mog.set(str_M3_mog)
        
        μ_ = (f_μ*100)
        str_μ = str('%.2f' % ((μ_)))
        txt_μ.set(str_μ)

        Izpis.insert(END, '1 - Zavorni moment prve osi \n M1_z = (p * (π*d^2/4)) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t = \t'
                     +txt_M1_z.get()+' Nm')
        Izpis.insert(END, '\n\n 2 - Zavorni moment druge osi \n M2_z = (p * (π*d^2/4)) * Rr2 * BF2 * n2  \t\t\t\t\t\t\t = \t'
                     +txt_M2_z.get()+' Nm')
        Izpis.insert(END, '\n\n 3 - Zavorni moment tretje osi \n M3_z = (p * (π*d^2/4)) * Rr3 * BF3 * n3  \t\t\t\t\t\t\t = \t'
                     +txt_M3_z.get()+' Nm')
        Izpis.insert(END, '\n\n 4 - Celoten zavorni moment \n M_cel = M1_z + M2_z + M3_z    \t\t\t\t\t\t\t = \t'+txt_M_cel.get()+' Nm')      
        Izpis.insert(END, '\n\n 5 - Teoretični zavorni učinek \n z = M_cel * (100-R)/(G1 * g * Rp1 + G2 * g * Rp2 + G3 * g * Rp3)  \t\t\t\t\t\t\t = \t'
                     +txt_zav_uc.get()+' % \t ≥   '+z_min.get()+' %')
        Izpis.insert(END, '\n\n 6 - Dinamična preobremenitev \n F_pr = (G1+G2+G3) * g * 13.5 * h / (100 * L)  \t\t\t\t\t\t\t = \t'
                     +txt_F_pr.get()+' N')
        Izpis.insert(END, '\n\n 7 - Dinamična obremenitev prve osi \n N1 = G1 * g + F_pr  \t\t\t\t\t\t\t = \t'+txt_N1.get()+' N')
        Izpis.insert(END, '\n\n 8 - Dinamična obremenitev druge osi \n N2 = G2 * g \t\t\t\t\t\t\t = \t'+txt_N2.get()+' N')
        Izpis.insert(END, '\n\n 9 - Dinamična obremenitev tretje osi \n N3 = G3 * g - F_pr \t\t\t\t\t\t\t = \t'+txt_N3.get()+' N')
        Izpis.insert(END, '\n\n 10 - Dinamični zavorni izkoristek prve osi \n z_N1 = M1_z * (100-R) / (N1 * Rp1)   \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' %')
        Izpis.insert(END, '\n\n 11 - Dinamični zavorni izkoristek druge osi \n z_N2 = M2_z * (100-R) / (N2 * Rp2)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' %')        
        Izpis.insert(END, '\n\n 12 - Dinamični zavorni izkoristek tretje osi \n z_N3 = M3_z * (100-R) / (N3 * Rp3)  \t\t\t\t\t\t\t = \t'
                     +txt_z_N3.get()+' %')
        Izpis.insert(END, '\n\n 13 - Največji mogoč zavorni moment prve osi \n M1_mog = (p_max * (π*d^2/4)) * Rr1 * BF1 * n1  \t\t\t\t\t\t\t=       \t'
                     +txt_M1_mog.get()+' Nm \t ≤   '+M1_max.get()+' Nm')
        Izpis.insert(END, '\n\n 14 - Največji mogoč zavorni moment druge osi \n M2_mog = (p_max * (π*d^2/4)) * Rr2 * BF2 * n2 \t\t\t\t\t\t\t=       \t'
                     +txt_M2_mog.get()+' Nm \t ≤   '+M2_max.get()+' Nm')
        Izpis.insert(END, '\n\n 15 - Največji mogoč zavorni moment tretje osi \n M3_mog = (p_max * (π*d^2/4)) * Rr3 * BF3 * n3 \t\t\t\t\t\t\t=       \t'
                     +txt_M3_mog.get()+' Nm \t ≤   '+M3_max.get()+' Nm')
        Izpis.insert(END, '\n\n 16 - Zdrs prve osi \n z_N1   ≤   μ * 100     \t\t\t\t\t\t\t = \t'
                     +txt_z_N1.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 17 - Zdrs druge osi \n z_N2   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N2.get()+' % \t ≤   '+txt_μ.get()+' %')
        Izpis.insert(END, '\n\n 18 - Zdrs tretje osi \n z_N2   ≤   μ * 100    \t\t\t\t\t\t\t = \t'
                     +txt_z_N3.get()+' % \t ≤   '+txt_μ.get()+' %')


def Vrsta_priklopnika(*args):
    '''Za delovanje funkcija potrebuje *args(nek argumen), ki ga dobi iz 
    menijev, kateri se odprejo (dropdown1,2 in 3). Funcija glede na izbrane 
    parametre izpiše potreben izračun.'''
    Izbris_parametrov()
    if dropdown1.get() == priklopnik[1] and dropdown2.get() == os[1] and dropdown3.get() == zavore[1]:
        for prostor in range(0,20):
            Label(f1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1, text='Medosna razdalja', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1, textvariable=L, width=10, font=('Times new roman', 11)).grid(row=1, column=3, sticky=W)
        enota_L = Label(f1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1, textvariable=p, width=10, font=('Times new roman', 11)).grid(row=3, column=3, sticky=W)
        enota_p = Label(f1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1, textvariable=p_max, width=10, font=('Times new roman', 11)).grid(row=4, column=3, sticky=W)
        enota_p_max = Label(f1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_pI = Label(f1, text='Prvi parameter zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_pI = Label(f1, text='pI =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_pI = Entry(f1, textvariable=pI, width=10, font=('Times new roman', 11)).grid(row=5, column=3, sticky=W)
        enota_pI = Label(f1, text='/', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_pII = Label(f1, text='Drugi parameter zavornega valja', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_pII = Label(f1, text='pII =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        vnos_pII = Entry(f1, textvariable=pII, width=10, font=('Times new roman', 11)).grid(row=6, column=3, sticky=W)
        enota_pII = Label(f1, text='/', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        pomen_z_min = Label(f1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_z_min = Label(f1, text='z_min =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        enota_z_min = Label(f1, text='%', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1, textvariable=z_min, width=10, font=('Times new roman', 11)).grid(row=7, column=3, sticky=W)
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_μ = Label(f1, text='μ =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_μ = Entry(f1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_μ = Label(f1, text='/', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        pomen_R = Label(f1, text='Upor ceste', font=('Times new roman', 11)).grid(row=9, column=0, sticky=W)
        oznaka_R = Label(f1, text='R =', font=('Times new roman', 11)).grid(row=9, column=2, sticky=W)
        vnos_R = Entry(f1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=9, column=3, sticky=W)
        enota_R = Label(f1, text='%', font=('Times new roman', 11)).grid(row=9, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1, text='PODATKI OSI', font=('Times new roman', 12, 'bold')).grid(row=10, column=0, sticky=W)
    
        pomen_G1 = Label(f1, text='Masa osi', font=('Times new roman', 11)).grid(row=11, column=0, sticky=W)
        oznaka_G1 = Label(f1, text='G1 =', font=('Times new roman', 11)).grid(row=11, column=2, sticky=W)
        vnos_G1 = Entry(f1, textvariable=G1, width=10, font=('Times new roman', 11)).grid(row=11, column=3, sticky=W)
        enota_G1 = Label(f1, text='kg', font=('Times new roman', 11)).grid(row=11, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_Rp1 = Label(f1, text='Rp1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_Rp1 = Entry(f1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=12, column=3, sticky=W)
        enota_Rp1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_Rb1 = Label(f1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_Rb1 = Label(f1, text='Rb1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        dropdown_Rb1 = ttk.Combobox(f1, textvariable=Rb1, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb1.current(0)
        dropdown_Rb1.grid(row=13, column=3, sticky=W)
        enota_Rb1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_BF1 = Label(f1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_BF1 = Label(f1, text='BF1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_BF1 = Entry(f1, textvariable=BF1, width=10, font=('Times new roman', 11)).grid(row=14, column=3, sticky=W)
        enota_BF1 = Label(f1, text='/', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_Rr1 = Label(f1, text='Rr1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_Rr1 = Entry(f1, textvariable=Rr1, width=10, font=('Times new roman', 11)).grid(row=15, column=3, sticky=W)
        enota_Rr1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_Ro1 = Label(f1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_Ro1 = Label(f1, text='Ro1 =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_Ro1 = Entry(f1, textvariable=Ro1, width=10, font=('Times new roman', 11)).grid(row=16, column=3, sticky=W)
        enota_Ro1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        pomen_n1 = Label(f1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=17, column=0, sticky=W)
        oznaka_n1 = Label(f1, text='n1 =', font=('Times new roman', 11)).grid(row=17, column=2, sticky=W)
        vnos_n1 = Entry(f1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=17, column=3, sticky=W)
        enota_n1 = Label(f1, text='/', font=('Times new roman', 11)).grid(row=17, column=4, sticky=W)
        
        pomen_M1_max = Label(f1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=18, column=0, sticky=W)
        oznaka_M1_max = Label(f1, text='M1_max =', font=('Times new roman', 11)).grid(row=18, column=2, sticky=W)
        vnos_M1_max = Entry(f1, textvariable=M1_max, width=10, font=('Times new roman', 11)).grid(row=18, column=3, sticky=W)
        enota_M1_max = Label(f1, text='Nm', font=('Times new roman', 11)).grid(row=18, column=4, sticky=W)       
   
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[2] and dropdown3.get() == zavore[1]:
    
        f0_1 = Canvas(f1)
        f0_1.pack(side=LEFT, fill=BOTH, expand=1)
        f01_scrollbar = ttk.Scrollbar(f1, orient=VERTICAL, command=f0_1.yview)
        f01_scrollbar.pack(side=RIGHT, fill=Y)
        f0_1.configure(yscrollcommand=f01_scrollbar.set)
        f0_1.bind('<Configure>', lambda e: f0_1.configure(scrollregion=f0_1.bbox('all')))
        f1_1 = Frame(f0_1)
        f0_1.create_window((0,0), window=f1_1, anchor='nw')     
        
        for prostor in range(0,29):
            Label(f1_1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1_1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1_1, text='Medosna razdalja', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1_1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1_1, textvariable=L, width=10, font=('Times new roman', 11)).grid(row=1, column=3, sticky=W)
        enota_L = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1_1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1_1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1_1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1_1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1_1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1_1, textvariable=p, width=10, font=('Times new roman', 11)).grid(row=3, column=3, sticky=W)
        enota_p = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1_1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1_1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1_1, textvariable=p_max, width=10, font=('Times new roman', 11)).grid(row=4, column=3, sticky=W)
        enota_p_max = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_pI = Label(f1_1, text='Prvi parameter zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_pI = Label(f1_1, text='pI =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_pI = Entry(f1_1, textvariable=pI, width=10, font=('Times new roman', 11)).grid(row=5, column=3, sticky=W)
        enota_pI = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_pII = Label(f1_1, text='Drugi parameter zavornega valja', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_pII = Label(f1_1, text='pII =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        vnos_pII = Entry(f1_1, textvariable=pII, width=10, font=('Times new roman', 11)).grid(row=6, column=3, sticky=W)
        enota_pII = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        pomen_z_min = Label(f1_1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_z_min = Label(f1_1, text='z_min =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        enota_z_min = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1_1, textvariable=z_min, width=10, font=('Times new roman', 11)).grid(row=7, column=3, sticky=W)
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1_1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_μ = Label(f1_1, text='μ =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_μ = Entry(f1_1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_μ = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        pomen_R = Label(f1_1, text='Upor ceste', font=('Times new roman', 11)).grid(row=9, column=0, sticky=W)
        oznaka_R = Label(f1_1, text='R =', font=('Times new roman', 11)).grid(row=9, column=2, sticky=W)
        vnos_R = Entry(f1_1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=9, column=3, sticky=W)
        enota_R = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=9, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1_1, text='PODATKI PRVE OSI', font=('Times new roman', 12, 'bold')).grid(row=10, column=0, sticky=W)
    
        pomen_G1 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=11, column=0, sticky=W)
        oznaka_G1 = Label(f1_1, text='G1 =', font=('Times new roman', 11)).grid(row=11, column=2, sticky=W)
        vnos_G1 = Entry(f1_1, textvariable=G1, width=10, font=('Times new roman', 11)).grid(row=11, column=3, sticky=W)
        enota_G1 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=11, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_Rp1 = Label(f1_1, text='Rp1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_Rp1 = Entry(f1_1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=12, column=3, sticky=W)
        enota_Rp1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_Rb1 = Label(f1_1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_Rb1 = Label(f1_1, text='Rb1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        dropdown_Rb1 = ttk.Combobox(f1_1, textvariable=Rb1, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb1.current(0)
        dropdown_Rb1.grid(row=13, column=3, sticky=W)
        enota_Rb1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_BF1 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_BF1 = Label(f1_1, text='BF1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_BF1 = Entry(f1_1, textvariable=BF1, width=10, font=('Times new roman', 11)).grid(row=14, column=3, sticky=W)
        enota_BF1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_Rr1 = Label(f1_1, text='Rr1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_Rr1 = Entry(f1_1, textvariable=Rr1, width=10, font=('Times new roman', 11)).grid(row=15, column=3, sticky=W)
        enota_Rr1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_Ro1 = Label(f1_1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_Ro1 = Label(f1_1, text='Ro1 =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_Ro1 = Entry(f1_1, textvariable=Ro1, width=10, font=('Times new roman', 11)).grid(row=16, column=3, sticky=W)
        enota_Ro1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        pomen_n1 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=17, column=0, sticky=W)
        oznaka_n1 = Label(f1_1, text='n1 =', font=('Times new roman', 11)).grid(row=17, column=2, sticky=W)
        vnos_n1 = Entry(f1_1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=17, column=3, sticky=W)
        enota_n1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=17, column=4, sticky=W)
        
        pomen_M1_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=18, column=0, sticky=W)
        oznaka_M1_max = Label(f1_1, text='M1_max =', font=('Times new roman', 11)).grid(row=18, column=2, sticky=W)
        vnos_M1_max = Entry(f1_1, textvariable=M1_max, width=10, font=('Times new roman', 11)).grid(row=18, column=3, sticky=W)
        enota_M1_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=18, column=4, sticky=W)
        
        Podatki_osi2 = Label(f1_1, text='PODATKI DRUGE OSI', font=('Times new roman', 12, 'bold')).grid(row=19, column=0, sticky=W)
        
        pomen_G2 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=20, column=0, sticky=W)
        oznaka_G2 = Label(f1_1, text='G2 =', font=('Times new roman', 11)).grid(row=20, column=2, sticky=W)
        vnos_G2 = Entry(f1_1, textvariable=G2, width=10, font=('Times new roman', 11)).grid(row=20, column=3, sticky=W)
        enota_G2 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=20, column=4, sticky=W)
        
        pomen_Rp2 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=21, column=0, sticky=W)
        oznaka_Rp2 = Label(f1_1, text='Rp2 =', font=('Times new roman', 11)).grid(row=21, column=2, sticky=W)
        vnos_Rp2 = Entry(f1_1, textvariable=Rp2, width=10, font=('Times new roman', 11)).grid(row=21, column=3, sticky=W)
        enota_Rp2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=21, column=4, sticky=W)
        
        pomen_Rb2 = Label(f1_1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=22, column=0, sticky=W)
        oznaka_Rb2 = Label(f1_1, text='Rb2 =', font=('Times new roman', 11)).grid(row=22, column=2, sticky=W)
        dropdown_Rb2 = ttk.Combobox(f1_1, textvariable=Rb2, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb2.current(0)
        dropdown_Rb2.grid(row=22, column=3, sticky=W)
        enota_Rb2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=22, column=4, sticky=W)
        
        pomen_BF2 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=23, column=0, sticky=W)
        oznaka_BF2 = Label(f1_1, text='BF2 =', font=('Times new roman', 11)).grid(row=23, column=2, sticky=W)
        vnos_BF2 = Entry(f1_1, textvariable=BF2, width=10, font=('Times new roman', 11)).grid(row=23, column=3, sticky=W)
        enota_BF2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=23, column=4, sticky=W)
        
        pomen_Rr2 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=24, column=0, sticky=W)
        oznaka_Rr2 = Label(f1_1, text='Rr2 =', font=('Times new roman', 11)).grid(row=24, column=2, sticky=W)
        vnos_Rr2 = Entry(f1_1, textvariable=Rr2, width=10, font=('Times new roman', 11)).grid(row=24, column=3, sticky=W)
        enota_Rr2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=24, column=4, sticky=W)
        
        pomen_Ro2 = Label(f1_1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=25, column=0, sticky=W)
        oznaka_Ro2 = Label(f1_1, text='Ro2 =', font=('Times new roman', 11)).grid(row=25, column=2, sticky=W)
        vnos_Ro2 = Entry(f1_1, textvariable=Ro2, width=10, font=('Times new roman', 11)).grid(row=25, column=3, sticky=W)
        enota_Ro2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=25, column=4, sticky=W)
        
        pomen_n2 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=26, column=0, sticky=W)
        oznaka_n2 = Label(f1_1, text='n2 =', font=('Times new roman', 11)).grid(row=26, column=2, sticky=W)
        vnos_n2 = Entry(f1_1, textvariable=n2, width=10, font=('Times new roman', 11)).grid(row=26, column=3, sticky=W)
        enota_n2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=26, column=4, sticky=W)
        
        pomen_M2_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=27, column=0, sticky=W)
        oznaka_M2_max = Label(f1_1, text='M2_max =', font=('Times new roman', 11)).grid(row=27, column=2, sticky=W)
        vnos_M2_max = Entry(f1_1, textvariable=M2_max, width=10, font=('Times new roman', 11)).grid(row=27, column=3, sticky=W)
        enota_M2_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=27, column=4, sticky=W)

    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[3] and dropdown3.get() == zavore[1]:             
        
        f0_1 = Canvas(f1)
        f0_1.pack(side=LEFT, fill=BOTH, expand=1)
        f01_scrollbar = ttk.Scrollbar(f1, orient=VERTICAL, command=f0_1.yview)
        f01_scrollbar.pack(side=RIGHT, fill=Y)
        f0_1.configure(yscrollcommand=f01_scrollbar.set)
        f0_1.bind('<Configure>', lambda e: f0_1.configure(scrollregion=f0_1.bbox('all')))
        f1_1 = Frame(f0_1)
        f0_1.create_window((0,0), window=f1_1, anchor='nw')     

        for prostor in range(0,39):
            Label(f1_1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1_1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1_1, text='Medosna razdalja', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1_1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1_1, textvariable=L, width=10, font=('Times new roman', 11)).grid(row=1, column=3, sticky=W)
        enota_L = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1_1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1_1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1_1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1_1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1_1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1_1, textvariable=p, width=10, font=('Times new roman', 11)).grid(row=3, column=3, sticky=W)
        enota_p = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1_1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1_1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1_1, textvariable=p_max, width=10, font=('Times new roman', 11)).grid(row=4, column=3, sticky=W)
        enota_p_max = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_pI = Label(f1_1, text='Prvi parameter zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_pI = Label(f1_1, text='pI =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_pI = Entry(f1_1, textvariable=pI, width=10, font=('Times new roman', 11)).grid(row=5, column=3, sticky=W)
        enota_pI = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_pII = Label(f1_1, text='Drugi parameter zavornega valja', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_pII = Label(f1_1, text='pII =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        vnos_pII = Entry(f1_1, textvariable=pII, width=10, font=('Times new roman', 11)).grid(row=6, column=3, sticky=W)
        enota_pII = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        pomen_z_min = Label(f1_1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_z_min = Label(f1_1, text='z_min =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        enota_z_min = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1_1, textvariable=z_min, width=10, font=('Times new roman', 11)).grid(row=7, column=3, sticky=W)
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1_1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_μ = Label(f1_1, text='μ =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_μ = Entry(f1_1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_μ = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        pomen_R = Label(f1_1, text='Upor ceste', font=('Times new roman', 11)).grid(row=9, column=0, sticky=W)
        oznaka_R = Label(f1_1, text='R =', font=('Times new roman', 11)).grid(row=9, column=2, sticky=W)
        vnos_R = Entry(f1_1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=9, column=3, sticky=W)
        enota_R = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=9, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1_1, text='PODATKI PRVE OSI', font=('Times new roman', 12, 'bold')).grid(row=10, column=0, sticky=W)
    
        pomen_G1 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=11, column=0, sticky=W)
        oznaka_G1 = Label(f1_1, text='G1 =', font=('Times new roman', 11)).grid(row=11, column=2, sticky=W)
        vnos_G1 = Entry(f1_1, textvariable=G1, width=10, font=('Times new roman', 11)).grid(row=11, column=3, sticky=W)
        enota_G1 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=11, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_Rp1 = Label(f1_1, text='Rp1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_Rp1 = Entry(f1_1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=12, column=3, sticky=W)
        enota_Rp1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_Rb1 = Label(f1_1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_Rb1 = Label(f1_1, text='Rb1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        dropdown_Rb1 = ttk.Combobox(f1_1, textvariable=Rb1, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb1.current(0)
        dropdown_Rb1.grid(row=13, column=3, sticky=W)
        enota_Rb1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_BF1 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_BF1 = Label(f1_1, text='BF1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_BF1 = Entry(f1_1, textvariable=BF1, width=10, font=('Times new roman', 11)).grid(row=14, column=3, sticky=W)
        enota_BF1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_Rr1 = Label(f1_1, text='Rr1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_Rr1 = Entry(f1_1, textvariable=Rr1, width=10, font=('Times new roman', 11)).grid(row=15, column=3, sticky=W)
        enota_Rr1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_Ro1 = Label(f1_1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_Ro1 = Label(f1_1, text='Ro1 =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_Ro1 = Entry(f1_1, textvariable=Ro1, width=10, font=('Times new roman', 11)).grid(row=16, column=3, sticky=W)
        enota_Ro1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        pomen_n1 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=17, column=0, sticky=W)
        oznaka_n1 = Label(f1_1, text='n1 =', font=('Times new roman', 11)).grid(row=17, column=2, sticky=W)
        vnos_n1 = Entry(f1_1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=17, column=3, sticky=W)
        enota_n1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=17, column=4, sticky=W)
        
        pomen_M1_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=18, column=0, sticky=W)
        oznaka_M1_max = Label(f1_1, text='M1_max =', font=('Times new roman', 11)).grid(row=18, column=2, sticky=W)
        vnos_M1_max = Entry(f1_1, textvariable=M1_max, width=10, font=('Times new roman', 11)).grid(row=18, column=3, sticky=W)
        enota_M1_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=18, column=4, sticky=W)
        
        Podatki_osi2 = Label(f1_1, text='PODATKI DRUGE OSI', font=('Times new roman', 12, 'bold')).grid(row=19, column=0, sticky=W)
        
        pomen_G2 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=20, column=0, sticky=W)
        oznaka_G2 = Label(f1_1, text='G2 =', font=('Times new roman', 11)).grid(row=20, column=2, sticky=W)
        vnos_G2 = Entry(f1_1, textvariable=G2, width=10, font=('Times new roman', 11)).grid(row=20, column=3, sticky=W)
        enota_G2 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=20, column=4, sticky=W)
        
        pomen_Rp2 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=21, column=0, sticky=W)
        oznaka_Rp2 = Label(f1_1, text='Rp2 =', font=('Times new roman', 11)).grid(row=21, column=2, sticky=W)
        vnos_Rp2 = Entry(f1_1, textvariable=Rp2, width=10, font=('Times new roman', 11)).grid(row=21, column=3, sticky=W)
        enota_Rp2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=21, column=4, sticky=W)
        
        pomen_Rb2 = Label(f1_1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=22, column=0, sticky=W)
        oznaka_Rb2 = Label(f1_1, text='Rb2 =', font=('Times new roman', 11)).grid(row=22, column=2, sticky=W)
        dropdown_Rb2 = ttk.Combobox(f1_1, textvariable=Rb2, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb2.current(0)
        dropdown_Rb2.grid(row=22, column=3, sticky=W)
        enota_Rb2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=22, column=4, sticky=W)
        
        pomen_BF2 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=23, column=0, sticky=W)
        oznaka_BF2 = Label(f1_1, text='BF2 =', font=('Times new roman', 11)).grid(row=23, column=2, sticky=W)
        vnos_BF2 = Entry(f1_1, textvariable=BF2, width=10, font=('Times new roman', 11)).grid(row=23, column=3, sticky=W)
        enota_BF2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=23, column=4, sticky=W)
        
        pomen_Rr2 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=24, column=0, sticky=W)
        oznaka_Rr2 = Label(f1_1, text='Rr2 =', font=('Times new roman', 11)).grid(row=24, column=2, sticky=W)
        vnos_Rr2 = Entry(f1_1, textvariable=Rr2, width=10, font=('Times new roman', 11)).grid(row=24, column=3, sticky=W)
        enota_Rr2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=24, column=4, sticky=W)
        
        pomen_Ro2 = Label(f1_1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=25, column=0, sticky=W)
        oznaka_Ro2 = Label(f1_1, text='Ro2 =', font=('Times new roman', 11)).grid(row=25, column=2, sticky=W)
        vnos_Ro2 = Entry(f1_1, textvariable=Ro2, width=10, font=('Times new roman', 11)).grid(row=25, column=3, sticky=W)
        enota_Ro2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=25, column=4, sticky=W)
        
        pomen_n2 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=26, column=0, sticky=W)
        oznaka_n2 = Label(f1_1, text='n2 =', font=('Times new roman', 11)).grid(row=26, column=2, sticky=W)
        vnos_n2 = Entry(f1_1, textvariable=n2, width=10, font=('Times new roman', 11)).grid(row=26, column=3, sticky=W)
        enota_n2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=26, column=4, sticky=W)
        
        pomen_M2_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=27, column=0, sticky=W)
        oznaka_M2_max = Label(f1_1, text='M2_max =', font=('Times new roman', 11)).grid(row=27, column=2, sticky=W)
        vnos_M2_max = Entry(f1_1, textvariable=M2_max, width=10, font=('Times new roman', 11)).grid(row=27, column=3, sticky=W)
        enota_M2_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=27, column=4, sticky=W)
        
        Podatki_osi3 = Label(f1_1, text='PODATKI TRETJE OSI', font=('Times new roman', 12, 'bold')).grid(row=28, column=0, sticky=W)
        
        pomen_G3 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=29, column=0, sticky=W)
        oznaka_G3 = Label(f1_1, text='G3 =', font=('Times new roman', 11)).grid(row=29, column=2, sticky=W)
        vnos_G3 = Entry(f1_1, textvariable=G3, width=10, font=('Times new roman', 11)).grid(row=29, column=3, sticky=W)
        enota_G3 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=29, column=4, sticky=W)
        
        pomen_Rp3 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=30, column=0, sticky=W)
        oznaka_Rp3 = Label(f1_1, text='Rp3 =', font=('Times new roman', 11)).grid(row=30, column=2, sticky=W)
        vnos_Rp3 = Entry(f1_1, textvariable=Rp3, width=10, font=('Times new roman', 11)).grid(row=30, column=3, sticky=W)
        enota_Rp3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=30, column=4, sticky=W)
        
        pomen_Rb3 = Label(f1_1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=31, column=0, sticky=W)
        oznaka_Rb3 = Label(f1_1, text='Rb3 =', font=('Times new roman', 11)).grid(row=31, column=2, sticky=W)
        dropdown_Rb3 = ttk.Combobox(f1_1, textvariable=Rb3, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb3.current(0)
        dropdown_Rb3.grid(row=31, column=3, sticky=W)
        enota_Rb3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=31, column=4, sticky=W)
        
        pomen_BF3 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=32, column=0, sticky=W)
        oznaka_BF3 = Label(f1_1, text='BF3 =', font=('Times new roman', 11)).grid(row=32, column=2, sticky=W)
        vnos_BF3 = Entry(f1_1, textvariable=BF3, width=10, font=('Times new roman', 11)).grid(row=32, column=3, sticky=W)
        enota_BF3 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=32, column=4, sticky=W)
        
        pomen_Rr3 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=33, column=0, sticky=W)
        oznaka_Rr3 = Label(f1_1, text='Rr3 =', font=('Times new roman', 11)).grid(row=33, column=2, sticky=W)
        vnos_Rr3 = Entry(f1_1, textvariable=Rr3, width=10, font=('Times new roman', 11)).grid(row=33, column=3, sticky=W)
        enota_Rr3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=33, column=4, sticky=W)
        
        pomen_Ro3 = Label(f1_1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=34, column=0, sticky=W)
        oznaka_Ro3 = Label(f1_1, text='Ro3 =', font=('Times new roman', 11)).grid(row=34, column=2, sticky=W)
        vnos_Ro3 = Entry(f1_1, textvariable=Ro3, width=10, font=('Times new roman', 11)).grid(row=34, column=3, sticky=W)
        enota_Ro3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=34, column=4, sticky=W)
        
        pomen_n3 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=35, column=0, sticky=W)
        oznaka_n3 = Label(f1_1, text='n3 =', font=('Times new roman', 11)).grid(row=35, column=2, sticky=W)
        vnos_n3 = Entry(f1_1, textvariable=n3, width=10, font=('Times new roman', 11)).grid(row=35, column=3, sticky=W)
        enota_n3 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=35, column=4, sticky=W)
        
        pomen_M3_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=36, column=0, sticky=W)
        oznaka_M3_max = Label(f1_1, text='M3_max =', font=('Times new roman', 11)).grid(row=36, column=2, sticky=W)
        vnos_M3_max = Entry(f1_1, textvariable=M3_max, width=10, font=('Times new roman', 11)).grid(row=36, column=3, sticky=W)
        enota_M3_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=36, column=4, sticky=W)
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[1] and dropdown3.get() == zavore[2]:
        for prostor in range(0,20):
            Label(f1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1, text='Medosna razdalja', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1, textvariable=L, width=10, font=('Times new roman', 11)).grid(row=1, column=3, sticky=W)
        enota_L = Label(f1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1, textvariable=p, width=10, font=('Times new roman', 11)).grid(row=3, column=3, sticky=W)
        enota_p = Label(f1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1, textvariable=p_max, width=10, font=('Times new roman', 11)).grid(row=4, column=3, sticky=W)
        enota_p_max = Label(f1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_d = Label(f1, text='Premer batnice zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_d = Label(f1, text='d =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_d = Entry(f1, textvariable=d, width=10, font=('Times new roman', 11)).grid(row=5, column=3, sticky=W)
        enota_d = Label(f1, text='m^2', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_z_min = Label(f1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_z_min = Label(f1, text='z_min =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        enota_z_min = Label(f1, text='%', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1, textvariable=z_min, width=10, font=('Times new roman', 11)).grid(row=6, column=3, sticky=W)
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_μ = Label(f1, text='μ =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        vnos_μ = Entry(f1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=7, column=3, sticky=W)
        enota_μ = Label(f1, text='/', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        pomen_R = Label(f1, text='Upor ceste', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_R = Label(f1, text='R =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_R = Entry(f1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_R = Label(f1, text='%', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1, text='PODATKI OSI', font=('Times new roman', 12, 'bold')).grid(row=10, column=0, sticky=W)
    
        pomen_G1 = Label(f1, text='Masa osi', font=('Times new roman', 11)).grid(row=11, column=0, sticky=W)
        oznaka_G1 = Label(f1, text='G1 =', font=('Times new roman', 11)).grid(row=11, column=2, sticky=W)
        vnos_G1 = Entry(f1, textvariable=G1, width=10, font=('Times new roman', 11)).grid(row=11, column=3, sticky=W)
        enota_G1 = Label(f1, text='kg', font=('Times new roman', 11)).grid(row=11, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_Rp1 = Label(f1, text='Rp1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_Rp1 = Entry(f1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=12, column=3, sticky=W)
        enota_Rp1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_Rb1 = Label(f1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_Rb1 = Label(f1, text='Rb1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        dropdown_Rb1 = ttk.Combobox(f1, textvariable=Rb1, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb1.current(0)
        dropdown_Rb1.grid(row=13, column=3, sticky=W)
        enota_Rb1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_BF1 = Label(f1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_BF1 = Label(f1, text='BF1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_BF1 = Entry(f1, textvariable=BF1, width=10, font=('Times new roman', 11)).grid(row=14, column=3, sticky=W)
        enota_BF1 = Label(f1, text='/', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_Rr1 = Label(f1, text='Rr1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_Rr1 = Entry(f1, textvariable=Rr1, width=10, font=('Times new roman', 11)).grid(row=15, column=3, sticky=W)
        enota_Rr1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_Ro1 = Label(f1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_Ro1 = Label(f1, text='Ro1 =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_Ro1 = Entry(f1, textvariable=Ro1, width=10, font=('Times new roman', 11)).grid(row=16, column=3, sticky=W)
        enota_Ro1 = Label(f1, text='m', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        pomen_n1 = Label(f1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=17, column=0, sticky=W)
        oznaka_n1 = Label(f1, text='n1 =', font=('Times new roman', 11)).grid(row=17, column=2, sticky=W)
        vnos_n1 = Entry(f1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=17, column=3, sticky=W)
        enota_n1 = Label(f1, text='/', font=('Times new roman', 11)).grid(row=17, column=4, sticky=W)
        
        pomen_M1_max = Label(f1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=18, column=0, sticky=W)
        oznaka_M1_max = Label(f1, text='M1_max =', font=('Times new roman', 11)).grid(row=18, column=2, sticky=W)
        vnos_M1_max = Entry(f1, textvariable=M1_max, width=10, font=('Times new roman', 11)).grid(row=18, column=3, sticky=W)
        enota_M1_max = Label(f1, text='Nm', font=('Times new roman', 11)).grid(row=18, column=4, sticky=W)       
   
        
    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[2] and dropdown3.get() == zavore[2]:
        
        f0_1 = Canvas(f1)
        f0_1.pack(side=LEFT, fill=BOTH, expand=1)
        f01_scrollbar = ttk.Scrollbar(f1, orient=VERTICAL, command=f0_1.yview)
        f01_scrollbar.pack(side=RIGHT, fill=Y)
        f0_1.configure(yscrollcommand=f01_scrollbar.set)
        f0_1.bind('<Configure>', lambda e: f0_1.configure(scrollregion=f0_1.bbox('all')))
        f1_1 = Frame(f0_1)
        f0_1.create_window((0,0), window=f1_1, anchor='nw')     
        
        for prostor in range(0,29):
            Label(f1_1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1_1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1_1, text='Medosna razdalja', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1_1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1_1, textvariable=L, width=10, font=('Times new roman', 11)).grid(row=1, column=3, sticky=W)
        enota_L = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1_1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1_1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1_1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1_1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1_1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1_1, textvariable=p, width=10, font=('Times new roman', 11)).grid(row=3, column=3, sticky=W)
        enota_p = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1_1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1_1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1_1, textvariable=p_max, width=10, font=('Times new roman', 11)).grid(row=4, column=3, sticky=W)
        enota_p_max = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_d = Label(f1_1, text='Premer batnice zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_d = Label(f1_1, text='d =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_d = Entry(f1_1, textvariable=d, width=10, font=('Times new roman', 11)).grid(row=5, column=3, sticky=W)
        enota_d = Label(f1_1, text='m^2', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_z_min = Label(f1_1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_z_min = Label(f1_1, text='z_min =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        enota_z_min = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1_1, textvariable=z_min, width=10, font=('Times new roman', 11)).grid(row=6, column=3, sticky=W)
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1_1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_μ = Label(f1_1, text='μ =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        vnos_μ = Entry(f1_1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=7, column=3, sticky=W)
        enota_μ = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        pomen_R = Label(f1_1, text='Upor ceste', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_R = Label(f1_1, text='R =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_R = Entry(f1_1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_R = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1_1, text='PODATKI PRVE OSI', font=('Times new roman', 12, 'bold')).grid(row=10, column=0, sticky=W)
    
        pomen_G1 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=11, column=0, sticky=W)
        oznaka_G1 = Label(f1_1, text='G1 =', font=('Times new roman', 11)).grid(row=11, column=2, sticky=W)
        vnos_G1 = Entry(f1_1, textvariable=G1, width=10, font=('Times new roman', 11)).grid(row=11, column=3, sticky=W)
        enota_G1 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=11, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_Rp1 = Label(f1_1, text='Rp1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_Rp1 = Entry(f1_1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=12, column=3, sticky=W)
        enota_Rp1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_Rb1 = Label(f1_1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_Rb1 = Label(f1_1, text='Rb1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        dropdown_Rb1 = ttk.Combobox(f1_1, textvariable=Rb1, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb1.current(0)
        dropdown_Rb1.grid(row=13, column=3, sticky=W)
        enota_Rb1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_BF1 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_BF1 = Label(f1_1, text='BF1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_BF1 = Entry(f1_1, textvariable=BF1, width=10, font=('Times new roman', 11)).grid(row=14, column=3, sticky=W)
        enota_BF1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_Rr1 = Label(f1_1, text='Rr1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_Rr1 = Entry(f1_1, textvariable=Rr1, width=10, font=('Times new roman', 11)).grid(row=15, column=3, sticky=W)
        enota_Rr1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_Ro1 = Label(f1_1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_Ro1 = Label(f1_1, text='Ro1 =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_Ro1 = Entry(f1_1, textvariable=Ro1, width=10, font=('Times new roman', 11)).grid(row=16, column=3, sticky=W)
        enota_Ro1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        pomen_n1 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=17, column=0, sticky=W)
        oznaka_n1 = Label(f1_1, text='n1 =', font=('Times new roman', 11)).grid(row=17, column=2, sticky=W)
        vnos_n1 = Entry(f1_1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=17, column=3, sticky=W)
        enota_n1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=17, column=4, sticky=W)
        
        pomen_M1_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=18, column=0, sticky=W)
        oznaka_M1_max = Label(f1_1, text='M1_max =', font=('Times new roman', 11)).grid(row=18, column=2, sticky=W)
        vnos_M1_max = Entry(f1_1, textvariable=M1_max, width=10, font=('Times new roman', 11)).grid(row=18, column=3, sticky=W)
        enota_M1_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=18, column=4, sticky=W)
        
        Podatki_osi2 = Label(f1_1, text='PODATKI DRUGE OSI', font=('Times new roman', 12, 'bold')).grid(row=19, column=0, sticky=W)
        
        pomen_G2 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=20, column=0, sticky=W)
        oznaka_G2 = Label(f1_1, text='G2 =', font=('Times new roman', 11)).grid(row=20, column=2, sticky=W)
        vnos_G2 = Entry(f1_1, textvariable=G2, width=10, font=('Times new roman', 11)).grid(row=20, column=3, sticky=W)
        enota_G2 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=20, column=4, sticky=W)
        
        pomen_Rp2 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=21, column=0, sticky=W)
        oznaka_Rp2 = Label(f1_1, text='Rp2 =', font=('Times new roman', 11)).grid(row=21, column=2, sticky=W)
        vnos_Rp2 = Entry(f1_1, textvariable=Rp2, width=10, font=('Times new roman', 11)).grid(row=21, column=3, sticky=W)
        enota_Rp2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=21, column=4, sticky=W)
        
        pomen_Rb2 = Label(f1_1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=22, column=0, sticky=W)
        oznaka_Rb2 = Label(f1_1, text='Rb2 =', font=('Times new roman', 11)).grid(row=22, column=2, sticky=W)
        dropdown_Rb2 = ttk.Combobox(f1_1, textvariable=Rb2, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb2.current(0)
        dropdown_Rb2.grid(row=22, column=3, sticky=W)
        enota_Rb2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=22, column=4, sticky=W)
        
        pomen_BF2 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=23, column=0, sticky=W)
        oznaka_BF2 = Label(f1_1, text='BF2 =', font=('Times new roman', 11)).grid(row=23, column=2, sticky=W)
        vnos_BF2 = Entry(f1_1, textvariable=BF2, width=10, font=('Times new roman', 11)).grid(row=23, column=3, sticky=W)
        enota_BF2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=23, column=4, sticky=W)
        
        pomen_Rr2 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=24, column=0, sticky=W)
        oznaka_Rr2 = Label(f1_1, text='Rr2 =', font=('Times new roman', 11)).grid(row=24, column=2, sticky=W)
        vnos_Rr2 = Entry(f1_1, textvariable=Rr2, width=10, font=('Times new roman', 11)).grid(row=24, column=3, sticky=W)
        enota_Rr2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=24, column=4, sticky=W)
        
        pomen_Ro2 = Label(f1_1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=25, column=0, sticky=W)
        oznaka_Ro2 = Label(f1_1, text='Ro2 =', font=('Times new roman', 11)).grid(row=25, column=2, sticky=W)
        vnos_Ro2 = Entry(f1_1, textvariable=Ro2, width=10, font=('Times new roman', 11)).grid(row=25, column=3, sticky=W)
        enota_Ro2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=25, column=4, sticky=W)
        
        pomen_n2 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=26, column=0, sticky=W)
        oznaka_n2 = Label(f1_1, text='n2 =', font=('Times new roman', 11)).grid(row=26, column=2, sticky=W)
        vnos_n2 = Entry(f1_1, textvariable=n2, width=10, font=('Times new roman', 11)).grid(row=26, column=3, sticky=W)
        enota_n2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=26, column=4, sticky=W)
        
        pomen_M2_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=27, column=0, sticky=W)
        oznaka_M2_max = Label(f1_1, text='M2_max =', font=('Times new roman', 11)).grid(row=27, column=2, sticky=W)
        vnos_M2_max = Entry(f1_1, textvariable=M2_max, width=10, font=('Times new roman', 11)).grid(row=27, column=3, sticky=W)
        enota_M2_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=27, column=4, sticky=W)

    elif dropdown1.get() == priklopnik[1] and dropdown2.get() == os[3] and dropdown3.get() == zavore[2]:
                
        f0_1 = Canvas(f1)
        f0_1.pack(side=LEFT, fill=BOTH, expand=1)
        f01_scrollbar = ttk.Scrollbar(f1, orient=VERTICAL, command=f0_1.yview)
        f01_scrollbar.pack(side=RIGHT, fill=Y)
        f0_1.configure(yscrollcommand=f01_scrollbar.set)
        f0_1.bind('<Configure>', lambda e: f0_1.configure(scrollregion=f0_1.bbox('all')))
        f1_1 = Frame(f0_1)
        f0_1.create_window((0,0), window=f1_1, anchor='nw')     

        for prostor in range(0,39):
            Label(f1_1, text='\t').grid(row=prostor, column=1)
        
        Podatki_priklopnika = Label(f1_1, text='PODATKI PRIKLOPNIKA', font=('Times new roman', 12, 'bold')).grid(row=0, column=0, sticky=W)
        
        pomen_L = Label(f1_1, text='Medosna razdalja', font=('Times new roman', 11)).grid(row=1, column=0, sticky=W)
        oznaka_L = Label(f1_1, text='L =', font=('Times new roman', 11)).grid(row=1, column=2, sticky=W)
        vnos_L = Entry(f1_1, textvariable=L, width=10, font=('Times new roman', 11)).grid(row=1, column=3, sticky=W)
        enota_L = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=1, column=4, sticky=W)
        
        pomen_h = Label(f1_1, text='Višina težišča', font=('Times new roman', 11)).grid(row=2, column=0, sticky=W)
        oznaka_h = Label(f1_1, text='h =', font=('Times new roman', 11)).grid(row=2, column=2, sticky=W)
        vnos_h = Entry(f1_1, textvariable=h, width=10, font=('Times new roman', 11)).grid(row=2, column=3, sticky=W)
        enota_h = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=2, column=4, sticky=W)
        
        pomen_p = Label(f1_1, text='Delovni tlak', font=('Times new roman', 11)).grid(row=3, column=0, sticky=W)
        oznaka_p = Label(f1_1, text='p = ', font=('Times new roman', 11)).grid(row=3, column=2, sticky=W)
        vnos_p = Entry(f1_1, textvariable=p, width=10, font=('Times new roman', 11)).grid(row=3, column=3, sticky=W)
        enota_p = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=3, column=4, sticky=W)
        
        pomen_p_max = Label(f1_1, text='Najvišji delovni tlak', font=('Times new roman', 11)).grid(row=4, column=0, sticky=W)
        oznaka_p_max = Label(f1_1, text='p_max =', font=('Times new roman', 11)).grid(row=4, column=2, sticky=W)
        vnos_p_max = Entry(f1_1, textvariable=p_max, width=10, font=('Times new roman', 11)).grid(row=4, column=3, sticky=W)
        enota_p_max = Label(f1_1, text='bar', font=('Times new roman', 11)).grid(row=4, column=4, sticky=W)
        
        pomen_d = Label(f1_1, text='Premer batnice zavornega valja', font=('Times new roman', 11)).grid(row=5, column=0, sticky=W)
        oznaka_d = Label(f1_1, text='d =', font=('Times new roman', 11)).grid(row=5, column=2, sticky=W)
        vnos_d = Entry(f1_1, textvariable=d, width=10, font=('Times new roman', 11)).grid(row=5, column=3, sticky=W)
        enota_d = Label(f1_1, text='m^2', font=('Times new roman', 11)).grid(row=5, column=4, sticky=W)
        
        pomen_z_min = Label(f1_1, text='Minimalen dovoljen zavorni učinek', font=('Times new roman', 11)).grid(row=6, column=0, sticky=W)
        oznaka_z_min = Label(f1_1, text='z_min =', font=('Times new roman', 11)).grid(row=6, column=2, sticky=W)
        enota_z_min = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=6, column=4, sticky=W)
        
        def fun_z_min(*args):
            '''Za delovanje funkcija potrebuje *args(nek argumen), 
            ki ga dobi iz menija dropdown4. Glede na izbrano
            hitrost določi kakšen je minimalni zavorni učinek
            po predpisih EU 2015/68'''
            vnos_z_min = Entry(f1_1, textvariable=z_min, width=10, font=('Times new roman', 11)).grid(row=6, column=3, sticky=W)
            if dropdown4.get() == hitrost[1]:        
                z_min.set(Predpisi_z[0])
            elif dropdown4.get() == hitrost[2]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[3]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[4]:      
                z_min.set(Predpisi_z[1])
            elif dropdown4.get() == hitrost[5]:      
                z_min.set(Predpisi_z[1])        
        dropdown4.bind('<<ComboboxSelected>>', fun_z_min)
               
        pomen_μ = Label(f1_1, text='Koeficient sojemanja', font=('Times new roman', 11)).grid(row=7, column=0, sticky=W)
        oznaka_μ = Label(f1_1, text='μ =', font=('Times new roman', 11)).grid(row=7, column=2, sticky=W)
        vnos_μ = Entry(f1_1, textvariable=μ, width=10, font=('Times new roman', 11)).grid(row=7, column=3, sticky=W)
        enota_μ = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=7, column=4, sticky=W)
        
        pomen_R = Label(f1_1, text='Upor ceste', font=('Times new roman', 11)).grid(row=8, column=0, sticky=W)
        oznaka_R = Label(f1_1, text='R =', font=('Times new roman', 11)).grid(row=8, column=2, sticky=W)
        vnos_R = Entry(f1_1, textvariable=R, width=10, font=('Times new roman', 11)).grid(row=8, column=3, sticky=W)
        enota_R = Label(f1_1, text='%', font=('Times new roman', 11)).grid(row=8, column=4, sticky=W)
        
        Podatki_osi1 = Label(f1_1, text='PODATKI PRVE OSI', font=('Times new roman', 12, 'bold')).grid(row=10, column=0, sticky=W)
    
        pomen_G1 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=11, column=0, sticky=W)
        oznaka_G1 = Label(f1_1, text='G1 =', font=('Times new roman', 11)).grid(row=11, column=2, sticky=W)
        vnos_G1 = Entry(f1_1, textvariable=G1, width=10, font=('Times new roman', 11)).grid(row=11, column=3, sticky=W)
        enota_G1 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=11, column=4, sticky=W)
        
        pomen_Rp1 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=12, column=0, sticky=W)
        oznaka_Rp1 = Label(f1_1, text='Rp1 =', font=('Times new roman', 11)).grid(row=12, column=2, sticky=W)
        vnos_Rp1 = Entry(f1_1, textvariable=Rp1, width=10, font=('Times new roman', 11)).grid(row=12, column=3, sticky=W)
        enota_Rp1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=12, column=4, sticky=W)
        
        pomen_Rb1 = Label(f1_1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=13, column=0, sticky=W)
        oznaka_Rb1 = Label(f1_1, text='Rb1 =', font=('Times new roman', 11)).grid(row=13, column=2, sticky=W)
        dropdown_Rb1 = ttk.Combobox(f1_1, textvariable=Rb1, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb1.current(0)
        dropdown_Rb1.grid(row=13, column=3, sticky=W)
        enota_Rb1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=13, column=4, sticky=W)
        
        pomen_BF1 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=14, column=0, sticky=W)
        oznaka_BF1 = Label(f1_1, text='BF1 =', font=('Times new roman', 11)).grid(row=14, column=2, sticky=W)
        vnos_BF1 = Entry(f1_1, textvariable=BF1, width=10, font=('Times new roman', 11)).grid(row=14, column=3, sticky=W)
        enota_BF1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=14, column=4, sticky=W)
        
        pomen_Rr1 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=15, column=0, sticky=W)
        oznaka_Rr1 = Label(f1_1, text='Rr1 =', font=('Times new roman', 11)).grid(row=15, column=2, sticky=W)
        vnos_Rr1 = Entry(f1_1, textvariable=Rr1, width=10, font=('Times new roman', 11)).grid(row=15, column=3, sticky=W)
        enota_Rr1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=15, column=4, sticky=W)
        
        pomen_Ro1 = Label(f1_1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=16, column=0, sticky=W)
        oznaka_Ro1 = Label(f1_1, text='Ro1 =', font=('Times new roman', 11)).grid(row=16, column=2, sticky=W)
        vnos_Ro1 = Entry(f1_1, textvariable=Ro1, width=10, font=('Times new roman', 11)).grid(row=16, column=3, sticky=W)
        enota_Ro1 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=16, column=4, sticky=W)
        
        pomen_n1 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=17, column=0, sticky=W)
        oznaka_n1 = Label(f1_1, text='n1 =', font=('Times new roman', 11)).grid(row=17, column=2, sticky=W)
        vnos_n1 = Entry(f1_1, textvariable=n1, width=10, font=('Times new roman', 11)).grid(row=17, column=3, sticky=W)
        enota_n1 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=17, column=4, sticky=W)
        
        pomen_M1_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=18, column=0, sticky=W)
        oznaka_M1_max = Label(f1_1, text='M1_max =', font=('Times new roman', 11)).grid(row=18, column=2, sticky=W)
        vnos_M1_max = Entry(f1_1, textvariable=M1_max, width=10, font=('Times new roman', 11)).grid(row=18, column=3, sticky=W)
        enota_M1_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=18, column=4, sticky=W)
        
        Podatki_osi2 = Label(f1_1, text='PODATKI DRUGE OSI', font=('Times new roman', 12, 'bold')).grid(row=19, column=0, sticky=W)
        
        pomen_G2 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=20, column=0, sticky=W)
        oznaka_G2 = Label(f1_1, text='G2 =', font=('Times new roman', 11)).grid(row=20, column=2, sticky=W)
        vnos_G2 = Entry(f1_1, textvariable=G2, width=10, font=('Times new roman', 11)).grid(row=20, column=3, sticky=W)
        enota_G2 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=20, column=4, sticky=W)
        
        pomen_Rp2 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=21, column=0, sticky=W)
        oznaka_Rp2 = Label(f1_1, text='Rp2 =', font=('Times new roman', 11)).grid(row=21, column=2, sticky=W)
        vnos_Rp2 = Entry(f1_1, textvariable=Rp2, width=10, font=('Times new roman', 11)).grid(row=21, column=3, sticky=W)
        enota_Rp2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=21, column=4, sticky=W)
        
        pomen_Rb2 = Label(f1_1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=22, column=0, sticky=W)
        oznaka_Rb2 = Label(f1_1, text='Rb2 =', font=('Times new roman', 11)).grid(row=22, column=2, sticky=W)
        dropdown_Rb2 = ttk.Combobox(f1_1, textvariable=Rb2, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb2.current(0)
        dropdown_Rb2.grid(row=22, column=3, sticky=W)
        enota_Rb2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=22, column=4, sticky=W)
        
        pomen_BF2 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=23, column=0, sticky=W)
        oznaka_BF2 = Label(f1_1, text='BF2 =', font=('Times new roman', 11)).grid(row=23, column=2, sticky=W)
        vnos_BF2 = Entry(f1_1, textvariable=BF2, width=10, font=('Times new roman', 11)).grid(row=23, column=3, sticky=W)
        enota_BF2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=23, column=4, sticky=W)
        
        pomen_Rr2 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=24, column=0, sticky=W)
        oznaka_Rr2 = Label(f1_1, text='Rr2 =', font=('Times new roman', 11)).grid(row=24, column=2, sticky=W)
        vnos_Rr2 = Entry(f1_1, textvariable=Rr2, width=10, font=('Times new roman', 11)).grid(row=24, column=3, sticky=W)
        enota_Rr2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=24, column=4, sticky=W)
        
        pomen_Ro2 = Label(f1_1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=25, column=0, sticky=W)
        oznaka_Ro2 = Label(f1_1, text='Ro2 =', font=('Times new roman', 11)).grid(row=25, column=2, sticky=W)
        vnos_Ro2 = Entry(f1_1, textvariable=Ro2, width=10, font=('Times new roman', 11)).grid(row=25, column=3, sticky=W)
        enota_Ro2 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=25, column=4, sticky=W)
        
        pomen_n2 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=26, column=0, sticky=W)
        oznaka_n2 = Label(f1_1, text='n2 =', font=('Times new roman', 11)).grid(row=26, column=2, sticky=W)
        vnos_n2 = Entry(f1_1, textvariable=n2, width=10, font=('Times new roman', 11)).grid(row=26, column=3, sticky=W)
        enota_n2 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=26, column=4, sticky=W)
        
        pomen_M2_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=27, column=0, sticky=W)
        oznaka_M2_max = Label(f1_1, text='M2_max =', font=('Times new roman', 11)).grid(row=27, column=2, sticky=W)
        vnos_M2_max = Entry(f1_1, textvariable=M2_max, width=10, font=('Times new roman', 11)).grid(row=27, column=3, sticky=W)
        enota_M2_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=27, column=4, sticky=W)
        
        Podatki_osi3 = Label(f1_1, text='PODATKI TRETJE OSI', font=('Times new roman', 12, 'bold')).grid(row=28, column=0, sticky=W)
        
        pomen_G3 = Label(f1_1, text='Masa osi', font=('Times new roman', 11)).grid(row=29, column=0, sticky=W)
        oznaka_G3 = Label(f1_1, text='G3 =', font=('Times new roman', 11)).grid(row=29, column=2, sticky=W)
        vnos_G3 = Entry(f1_1, textvariable=G3, width=10, font=('Times new roman', 11)).grid(row=29, column=3, sticky=W)
        enota_G3 = Label(f1_1, text='kg', font=('Times new roman', 11)).grid(row=29, column=4, sticky=W)
        
        pomen_Rp3 = Label(f1_1, text='Radij pnevmatike', font=('Times new roman', 11)).grid(row=30, column=0, sticky=W)
        oznaka_Rp3 = Label(f1_1, text='Rp3 =', font=('Times new roman', 11)).grid(row=30, column=2, sticky=W)
        vnos_Rp3 = Entry(f1_1, textvariable=Rp3, width=10, font=('Times new roman', 11)).grid(row=30, column=3, sticky=W)
        enota_Rp3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=30, column=4, sticky=W)
        
        pomen_Rb3 = Label(f1_1, text='Radij zavornega bobna', font=('Times new roman', 11)).grid(row=31, column=0, sticky=W)
        oznaka_Rb3 = Label(f1_1, text='Rb3 =', font=('Times new roman', 11)).grid(row=31, column=2, sticky=W)
        dropdown_Rb3 = ttk.Combobox(f1_1, textvariable=Rb3, value=Radij_bobna, width=10, font=('Times new roman', 11))
        dropdown_Rb3.current(0)
        dropdown_Rb3.grid(row=31, column=3, sticky=W)
        enota_Rb3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=31, column=4, sticky=W)
        
        pomen_BF3 = Label(f1_1, text='Faktor zaviranja', font=('Times new roman', 11)).grid(row=32, column=0, sticky=W)
        oznaka_BF3 = Label(f1_1, text='BF3 =', font=('Times new roman', 11)).grid(row=32, column=2, sticky=W)
        vnos_BF3 = Entry(f1_1, textvariable=BF3, width=10, font=('Times new roman', 11)).grid(row=32, column=3, sticky=W)
        enota_BF3 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=32, column=4, sticky=W)
        
        pomen_Rr3 = Label(f1_1, text='Radij zavorne ročice', font=('Times new roman', 11)).grid(row=33, column=0, sticky=W)
        oznaka_Rr3 = Label(f1_1, text='Rr3 =', font=('Times new roman', 11)).grid(row=33, column=2, sticky=W)
        vnos_Rr3 = Entry(f1_1, textvariable=Rr3, width=10, font=('Times new roman', 11)).grid(row=33, column=3, sticky=W)
        enota_Rr3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=33, column=4, sticky=W)
        
        pomen_Ro3 = Label(f1_1, text='Radij odmikača', font=('Times new roman', 11)).grid(row=34, column=0, sticky=W)
        oznaka_Ro3 = Label(f1_1, text='Ro3 =', font=('Times new roman', 11)).grid(row=34, column=2, sticky=W)
        vnos_Ro3 = Entry(f1_1, textvariable=Ro3, width=10, font=('Times new roman', 11)).grid(row=34, column=3, sticky=W)
        enota_Ro3 = Label(f1_1, text='m', font=('Times new roman', 11)).grid(row=34, column=4, sticky=W)
        
        pomen_n3 = Label(f1_1, text='Število zavornih valjev na os', font=('Times new roman', 11)).grid(row=35, column=0, sticky=W)
        oznaka_n3 = Label(f1_1, text='n3 =', font=('Times new roman', 11)).grid(row=35, column=2, sticky=W)
        vnos_n3 = Entry(f1_1, textvariable=n3, width=10, font=('Times new roman', 11)).grid(row=35, column=3, sticky=W)
        enota_n3 = Label(f1_1, text='/', font=('Times new roman', 11)).grid(row=35, column=4, sticky=W)
        
        pomen_M3_max = Label(f1_1, text='Največji dovoljen zavorni moment', font=('Times new roman', 11)).grid(row=36, column=0, sticky=W)
        oznaka_M3_max = Label(f1_1, text='M3_max =', font=('Times new roman', 11)).grid(row=36, column=2, sticky=W)
        vnos_M3_max = Entry(f1_1, textvariable=M3_max, width=10, font=('Times new roman', 11)).grid(row=36, column=3, sticky=W)
        enota_M3_max = Label(f1_1, text='Nm', font=('Times new roman', 11)).grid(row=36, column=4, sticky=W)
        

        
def Izbris_parametrov():
    '''Fukncija izbriše vsak parameter,
    ki je znotraj okvirja f1, ko zamenjamo 
    kombinacijo dropdown menijev'''
    for parametri_izracun in f1.winfo_children():
        parametri_izracun.destroy()

def Izbris_rezultatov():
    '''Funcija izbriše prikazane rezultate'''
    Izpis.delete('1.0', END)
    return
 


'''Izbira vrste priklopnika'''
dropdown1 = ttk.Combobox(f0, value=priklopnik, width = 22, font=('Times new roman', 11))
dropdown1.current(0) # Izberemo kater element combobox prikaže
dropdown1.place(x=5, y=5)    
dropdown1.bind('<<ComboboxSelected>>', Vrsta_priklopnika)

dropdown2 = ttk.Combobox(f0, value=os, width = 22, font=('Times new roman', 11))
dropdown2.current(0)
dropdown2.place(x=5, y=30)
dropdown2.bind('<<ComboboxSelected>>', Vrsta_priklopnika)

dropdown3 = ttk.Combobox(f0, value=zavore, width = 22, font=('Times new roman', 11))
dropdown3.current(0)
dropdown3.place(x=5, y=55)
dropdown3.bind('<<ComboboxSelected>>', Vrsta_priklopnika)

dropdown4 = ttk.Combobox(f0, value=hitrost, width = 22, font=('Times new roman', 11))
dropdown4.current(0)
dropdown4.place(x=5, y=80)
dropdown4_Label = Label(f0, text='km/h', font=('Times new roman', 11)).place(x=190, y=80)
dropdown4.bind('<<ComboboxSelected>>', Vrsta_priklopnika)




'''Gumbi'''       
Izracunaj = Button(f0, text='Izračunaj', width=10, command=Enacbe, font=('Times new roman', 11))
Izracunaj.place(x=300, y=50)        

Resetiraj = Button(f0, text='Resetiraj', width=10, command=Izbris_rezultatov, font=('Times new roman', 11))
Resetiraj.place(x=400, y=50)



root.mainloop() # Ustvariti moramo zanko, ki poganja program
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Program Files\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\Miha\AppData\Local\Temp\ipykernel_8060\3410572212.py", line 169, in Enacbe
#     f_p = float(p.get())
# ValueError: could not convert string to float: ''
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Program Files\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\Miha\AppData\Local\Temp\ipykernel_8060\3410572212.py", line 179, in Enacbe
#     f_L = float(L.get())
# ValueError: could not convert string to float: ''
